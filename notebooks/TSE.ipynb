# %%
import pandas as pd

tse = pd.read_csv('/home/lisamenezes/Searches/pipeline-dados-PDM/data/tse/votacao_secao_2012_GO/votacao_secao_2012_GO.csv', 
                  encoding='Latin-1', sep=';')
tse
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0        27/07/2021   17:04:35         2012                2
# 1        27/07/2021   17:04:35         2012                2
# 2        27/07/2021   17:04:35         2012                2
# 3        27/07/2021   17:04:35         2012                2
# 4        27/07/2021   17:04:35         2012                2
# ...             ...        ...          ...              ...
# 1070378  27/07/2021   17:04:35         2012                2
# 1070379  27/07/2021   17:04:35         2012                2
# 1070380  27/07/2021   17:04:35         2012                2
# 1070381  27/07/2021   17:04:35         2012                2
# 1070382  27/07/2021   17:04:35         2012                2
#
#            NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO              DS_ELEICAO  \
# 0        Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 1        Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 2        Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 3        Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 4        Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# ...                    ...       ...         ...                     ...
# 1070378  Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 1070379  Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 1070380  Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 1070381  Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
# 1070382  Eleição Ordinária         1          47  ELEIÇÃO MUNICIPAL 2012
#
#          DT_ELEICAO TP_ABRANGENCIA  ... CD_MUNICIPIO           NM_MUNICIPIO  \
# 0        07/10/2012              M  ...        93360        ABADIA DE GOIÁS
# 1        07/10/2012              M  ...        93360        ABADIA DE GOIÁS
# 2        07/10/2012              M  ...        93360        ABADIA DE GOIÁS
# 3        07/10/2012              M  ...        93360        ABADIA DE GOIÁS
# 4        07/10/2012              M  ...        93360        ABADIA DE GOIÁS
# ...             ...            ...  ...          ...                    ...
# 1070378  07/10/2012              M  ...        93343  ÁGUAS LINDAS DE GOIÁS
# 1070379  07/10/2012              M  ...        93343  ÁGUAS LINDAS DE GOIÁS
# 1070380  07/10/2012              M  ...        93343  ÁGUAS LINDAS DE GOIÁS
# 1070381  07/10/2012              M  ...        93343  ÁGUAS LINDAS DE GOIÁS
# 1070382  07/10/2012              M  ...        93343  ÁGUAS LINDAS DE GOIÁS
#
#         NR_ZONA  NR_SECAO CD_CARGO  DS_CARGO  NR_VOTAVEL  \
# 0            56        57       11  Prefeito          15
# 1            56        57       11  Prefeito          45
# 2            56        57       11  Prefeito          55
# 3            56        57       11  Prefeito          95
# 4            56        57       11  Prefeito          96
# ...         ...       ...      ...       ...         ...
# 1070378      28       187       13  Vereador       28555
# 1070379      28       187       13  Vereador       28333
# 1070380      28       187       13  Vereador       14014
# 1070381      28       187       13  Vereador          95
# 1070382      28       187       13  Vereador       13000
#
#                                NM_VOTAVEL QT_VOTOS  NR_LOCAL_VOTACAO
# 0                   IOLANY CAROLINA NUNES       80              1015
# 1                     ROMES GOMES E SILVA       91              1015
# 2               VALDECI SALVIANO MENDONÇA       95              1015
# 3                             VOTO BRANCO        7              1015
# 4                               VOTO NULO       17              1015
# ...                                   ...      ...               ...
# 1070378             ULISSES DA SILVA LEAL        1              1210
# 1070379          VALDEVINO GOMES DA SILVA        3              1210
# 1070380           VICENTE MANOEL DA SILVA        4              1210
# 1070381                       VOTO BRANCO        1              1210
# 1070382  WILLEM MADISON DA SILVA TEIXEIRA        1              1210
#
# [1070383 rows x 23 columns]

# %%
tse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070383 entries, 0 to 1070382
# Data columns (total 23 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   DT_GERACAO        1070383 non-null  object
#  1   HH_GERACAO        1070383 non-null  object
#  2   ANO_ELEICAO       1070383 non-null  int64
#  3   CD_TIPO_ELEICAO   1070383 non-null  int64
#  4   NM_TIPO_ELEICAO   1070383 non-null  object
#  5   NR_TURNO          1070383 non-null  int64
#  6   CD_ELEICAO        1070383 non-null  int64
#  7   DS_ELEICAO        1070383 non-null  object
#  8   DT_ELEICAO        1070383 non-null  object
#  9   TP_ABRANGENCIA    1070383 non-null  object
#  10  SG_UF             1070383 non-null  object
#  11  SG_UE             1070383 non-null  int64
#  12  NM_UE             1070383 non-null  object
#  13  CD_MUNICIPIO      1070383 non-null  int64
#  14  NM_MUNICIPIO      1070383 non-null  object
#  15  NR_ZONA           1070383 non-null  int64
#  16  NR_SECAO          1070383 non-null  int64
#  17  CD_CARGO          1070383 non-null  int64
#  18  DS_CARGO          1070383 non-null  object
#  19  NR_VOTAVEL        1070383 non-null  int64
#  20  NM_VOTAVEL        1070383 non-null  object
#  21  QT_VOTOS          1070383 non-null  int64
#  22  NR_LOCAL_VOTACAO  1070383 non-null  int64
# dtypes: int64(12), object(11)
# memory usage: 187.8+ MB

# %%
tse['CD_CARGO'].unique()
# Out:
# array([11, 13])

# %% [markdown]
# ### features importantes

# %%
print(tse.columns)
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'NR_ZONA', 'NR_SECAO', 'CD_CARGO', 'DS_CARGO',
#        'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_LOCAL_VOTACAO'],
#       dtype='object')

# %%
tse = tse[['ANO_ELEICAO','NM_MUNICIPIO','NR_ZONA', 'NR_SECAO', 'CD_TIPO_ELEICAO','NR_TURNO', 'DS_CARGO', 'NM_VOTAVEL', 'NR_VOTAVEL', 'QT_VOTOS']]

# %% [markdown]
# #### Processamento das strings

# %%
from unidecode import unidecode

# transformações nos dados
# 
# Função para transformar texto: remover acentos e deixar em maiúsculas
def transformar_string(valor):
    if isinstance(valor, str):  # Verifica se é uma string
        return unidecode(valor).upper()
    return valor  # Retorna o valor original se não for string

# Aplica a transformação em todas as colunas de tipo string
for col in tse.select_dtypes(include=["object"]).columns:
    tse[col] = tse[col].apply(transformar_string)

tse
# Out:
# /tmp/ipykernel_2019608/2211555752.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tse[col] = tse[col].apply(transformar_string)
#          ANO_ELEICAO           NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 0               2012        ABADIA DE GOIAS       56        57
# 1               2012        ABADIA DE GOIAS       56        57
# 2               2012        ABADIA DE GOIAS       56        57
# 3               2012        ABADIA DE GOIAS       56        57
# 4               2012        ABADIA DE GOIAS       56        57
# ...              ...                    ...      ...       ...
# 1070378         2012  AGUAS LINDAS DE GOIAS       28       187
# 1070379         2012  AGUAS LINDAS DE GOIAS       28       187
# 1070380         2012  AGUAS LINDAS DE GOIAS       28       187
# 1070381         2012  AGUAS LINDAS DE GOIAS       28       187
# 1070382         2012  AGUAS LINDAS DE GOIAS       28       187
#
#          CD_TIPO_ELEICAO  NR_TURNO  DS_CARGO  \
# 0                      2         1  PREFEITO
# 1                      2         1  PREFEITO
# 2                      2         1  PREFEITO
# 3                      2         1  PREFEITO
# 4                      2         1  PREFEITO
# ...                  ...       ...       ...
# 1070378                2         1  VEREADOR
# 1070379                2         1  VEREADOR
# 1070380                2         1  VEREADOR
# 1070381                2         1  VEREADOR
# 1070382                2         1  VEREADOR
#
#                                NM_VOTAVEL  QT_VOTOS
# 0                   IOLANY CAROLINA NUNES        80
# 1                     ROMES GOMES E SILVA        91
# 2               VALDECI SALVIANO MENDONCA        95
# 3                             VOTO BRANCO         7
# 4                               VOTO NULO        17
# ...                                   ...       ...
# 1070378             ULISSES DA SILVA LEAL         1
# 1070379          VALDEVINO GOMES DA SILVA         3
# 1070380           VICENTE MANOEL DA SILVA         4
# 1070381                       VOTO BRANCO         1
# 1070382  WILLEM MADISON DA SILVA TEIXEIRA         1
#
# [1070383 rows x 9 columns]

# %%
print(tse.isnull().sum())
# Out:
# ANO_ELEICAO        0
# NM_MUNICIPIO       0
# NR_ZONA            0
# NR_SECAO           0
# CD_TIPO_ELEICAO    0
# NR_TURNO           0
# DS_CARGO           0
# NM_VOTAVEL         0
# QT_VOTOS           0
# dtype: int64

# %% [markdown]
# ### Filtros

# %%
tse.head()
# Out:
#    ANO_ELEICAO     NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  NR_TURNO  \
# 0         2012  ABADIA DE GOIAS       56        57                2         1
# 1         2012  ABADIA DE GOIAS       56        57                2         1
# 2         2012  ABADIA DE GOIAS       56        57                2         1
# 3         2012  ABADIA DE GOIAS       56        57                2         1
# 4         2012  ABADIA DE GOIAS       56        57                2         1
#
#    DS_CARGO                 NM_VOTAVEL  QT_VOTOS
# 0  PREFEITO      IOLANY CAROLINA NUNES        80
# 1  PREFEITO        ROMES GOMES E SILVA        91
# 2  PREFEITO  VALDECI SALVIANO MENDONCA        95
# 3  PREFEITO                VOTO BRANCO         7
# 4  PREFEITO                  VOTO NULO        17

# %%
tse['NM_MUNICIPIO'].unique()
# Out:
# array(['ABADIA DE GOIAS', 'ABADIANIA', 'ACREUNA', 'ADELANDIA', 'ALEXANIA',
#        'ALOANDIA', 'ALTO HORIZONTE', 'ALTO PARAISO DE GOIAS',
#        'ALVORADA DO NORTE', 'AMARALINA', 'AMERICANO DO BRASIL',
#        'AMORINOPOLIS', 'ANHANGUERA', 'ANICUNS', 'ANAPOLIS',
#        'APARECIDA DE GOIANIA', 'APARECIDA DO RIO DOCE', 'APORE',
#        'ARAGARCAS', 'ARAGOIANIA', 'ARAGUAPAZ', 'ARACU', 'ARENOPOLIS',
#        'ARUANA', 'AURILANDIA', 'AVELINOPOLIS', 'BALIZA', 'BARRO ALTO',
#        'BELA VISTA DE GOIAS', 'BOM JARDIM DE GOIAS', 'BOM JESUS DE GOIAS',
#        'BONFINOPOLIS', 'BONOPOLIS', 'BRAZABRANTES', 'BRITANIA',
#        'BURITI ALEGRE', 'BURITI DE GOIAS', 'BURITINOPOLIS', 'CABECEIRAS',
#        'CACHOEIRA ALTA', 'CACHOEIRA DE GOIAS', 'CACHOEIRA DOURADA',
#        'CAIAPONIA', 'CALDAS NOVAS', 'CALDAZINHA', 'CAMPESTRE DE GOIAS',
#        'CAMPINACU', 'CAMPINORTE', 'CAMPO ALEGRE DE GOIAS',
#        'CAMPO LIMPO DE GOIAS', 'CAMPOS BELOS', 'CAMPOS VERDES',
#        'CARMO DO RIO VERDE', 'CASTELANDIA', 'CATALAO', 'CATURAI',
#        'CAVALCANTE', 'CACU', 'CERES', 'CEZARINA', 'CHAPADAO DO CEU',
#        'CIDADE OCIDENTAL', 'COCALZINHO DE GOIAS', 'COLINAS DO SUL',
#        'CORUMBAIBA', 'CORUMBA DE GOIAS', 'CRISTALINA', 'CRISTIANOPOLIS',
#        'CRIXAS', 'CROMINIA', 'CUMARI', 'CORREGO DO OURO', 'DAMIANOPOLIS',
#        'DAMOLANDIA', 'DAVINOPOLIS', 'DIORAMA', 'DIVINOPOLIS DE GOIAS',
#        'DOVERLANDIA', 'EDEALINA', 'EDEIA', 'ESTRELA DO NORTE', 'FAINA',
#        'FAZENDA NOVA', 'FIRMINOPOLIS', 'FLORES DE GOIAS', 'FORMOSA',
#        'FORMOSO', 'GAMELEIRA DE GOIAS', 'GOIANDIRA', 'GOIANIRA',
#        'GOIANAPOLIS', 'GOIANESIA', 'GOIATUBA', 'GOIAS', 'GOIANIA',
#        'GOUVELANDIA', 'GUAPO', 'GUARANI DE GOIAS', 'GUARAITA', 'GUARINOS',
#        'HEITORAI', 'HIDROLINA', 'HIDROLANDIA', 'IACIARA', 'INACIOLANDIA',
#        'INDIARA', 'INHUMAS', 'IPAMERI', 'IPIRANGA DE GOIAS', 'IPORA',
#        'ISRAELANDIA', 'ITABERAI', 'ITAGUARI', 'ITAGUARU', 'ITAJA',
#        'ITAPACI', 'ITAPIRAPUA', 'ITAPURANGA', 'ITARUMA', 'ITAUCU',
#        'ITUMBIARA', 'IVOLANDIA', 'JANDAIA', 'JARAGUA', 'JATAI', 'JAUPACI',
#        'JESUPOLIS', 'JOVIANIA', 'JUSSARA', 'LAGOA SANTA',
#        'LEOPOLDO DE BULHOES', 'LUZIANIA', 'MAIRIPOTABA', 'MAMBAI',
#        'MARA ROSA', 'MARZAGAO', 'MATRINCHA', 'MAURILANDIA',
#        'MIMOSO DE GOIAS', 'MINACU', 'MINEIROS', 'MOIPORA',
#        'MONTE ALEGRE DE GOIAS', 'MONTES CLAROS DE GOIAS', 'MONTIVIDIU',
#        'MONTIVIDIU DO NORTE', 'MORRINHOS', 'MORRO AGUDO DE GOIAS',
#        'MOSSAMEDES', 'MOZARLANDIA', 'MUNDO NOVO', 'MUTUNOPOLIS',
#        'NAZARIO', 'NEROPOLIS', 'NIQUELANDIA', 'NOVA AMERICA',
#        'NOVA AURORA', 'NOVA CRIXAS', 'NOVA GLORIA',
#        'NOVA IGUACU DE GOIAS', 'NOVA ROMA', 'NOVA VENEZA', 'NOVO BRASIL',
#        'NOVO GAMA', 'NOVO PLANALTO', 'ORIZONA', 'OURO VERDE DE GOIAS',
#        'OUVIDOR', 'PADRE BERNARDO', 'PALESTINA DE GOIAS',
#        'PALMEIRAS DE GOIAS', 'PALMELO', 'PALMINOPOLIS', 'PANAMA',
#        'PARANAIGUARA', 'PARAUNA', 'PEROLANDIA', 'PETROLINA DE GOIAS',
#        'PILAR DE GOIAS', 'PIRACANJUBA', 'PIRANHAS', 'PIRENOPOLIS',
#        'PIRES DO RIO', 'PLANALTINA', 'PONTALINA', 'PORANGATU',
#        'PORTEIRAO', 'PORTELANDIA', 'POSSE', 'PROFESSOR JAMIL',
#        'QUIRINOPOLIS', 'RIALMA', 'RIANAPOLIS', 'RIO QUENTE', 'RIO VERDE',
#        'RUBIATABA', 'SANCLERLANDIA', 'SANTA BARBARA DE GOIAS',
#        'SANTA CRUZ DE GOIAS', 'SANTA FE DE GOIAS',
#        'SANTA HELENA DE GOIAS', 'SANTA ISABEL', 'SANTA RITA DO ARAGUAIA',
#        'SANTA RITA DO NOVO DESTINO', 'SANTA ROSA DE GOIAS',
#        'SANTA TEREZA DE GOIAS', 'SANTA TEREZINHA DE GOIAS',
#        'SANTO ANTONIO DA BARRA', 'SANTO ANTONIO DE GOIAS',
#        'SANTO ANTONIO DO DESCOBERTO', 'SENADOR CANEDO', 'SERRANOPOLIS',
#        'SILVANIA', 'SIMOLANDIA', 'SAO DOMINGOS', 'SAO FRANCISCO DE GOIAS',
#        'SAO JOAO D ALIANCA', 'SAO JOAO DA PARAUNA', 'SAO LUIZ DO NORTE',
#        'SAO LUIS DE MONTES BELOS', 'SAO MIGUEL DO ARAGUAIA',
#        'SAO MIGUEL DO PASSA QUATRO', 'SAO PATRICIO', 'SAO SIMAO',
#        'SITIO D ABADIA', 'TAQUARAL DE GOIAS', 'TERESINA DE GOIAS',
#        'TEREZOPOLIS DE GOIAS', 'TRINDADE', 'TROMBAS', 'TRES RANCHOS',
#        'TURVELANDIA', 'TURVANIA', 'UIRAPURU', 'URUANA', 'URUACU',
#        'URUTAI', 'VALPARAISO DE GOIAS', 'VARJAO', 'VIANOPOLIS',
#        'VICENTINOPOLIS', 'VILA BOA', 'VILA PROPICIO',
#        'AGUA FRIA DE GOIAS', 'AGUA LIMPA', 'AGUAS LINDAS DE GOIAS'],
#       dtype=object)

# %%
tse = tse[tse["NM_MUNICIPIO"] == 'GOIANIA']
tse = tse[tse["DS_CARGO"] == 'VEREADOR']

# %%
tse
# Out:
#         ANO_ELEICAO NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  \
# 337443         2012      GOIANIA        1         1                2
# 337444         2012      GOIANIA        1         1                2
# 337445         2012      GOIANIA        1         1                2
# 337446         2012      GOIANIA        1         1                2
# 337447         2012      GOIANIA        1         1                2
# ...             ...          ...      ...       ...              ...
# 645861         2012      GOIANIA      147       451                2
# 645862         2012      GOIANIA      147       451                2
# 645863         2012      GOIANIA      147       451                2
# 645864         2012      GOIANIA      147       451                2
# 645865         2012      GOIANIA      147       451                2
#
#         NR_TURNO  DS_CARGO                        NM_VOTAVEL  QT_VOTOS
# 337443         1  VEREADOR              ADAILA LUZ PAES LEME         1
# 337444         1  VEREADOR  ADRIANA RODRIGUES PINHEIRO DIOGO         1
# 337445         1  VEREADOR       ADRIANO RODRIGO LINO MALTEZ         3
# 337446         1  VEREADOR       AGNALDO BURJACK EVANGELISTA         1
# 337447         1  VEREADOR           AILMA MARIA DE OLIVEIRA         3
# ...          ...       ...                               ...       ...
# 645861         1  VEREADOR                       VOTO BRANCO        21
# 645862         1  VEREADOR                         VOTO NULO        20
# 645863         1  VEREADOR          WALDEMIR SOARES DA SILVA         3
# 645864         1  VEREADOR           WELINGTON PEIXOTO MOURA         3
# 645865         1  VEREADOR       ZANDER FABIO ALVES DA COSTA         1
#
# [285225 rows x 9 columns]

# %% [markdown]
# # Agregação com tabela zonas

# %%
zonas_info = pd.read_csv('/home/lisamenezes/Searches/pipeline-dados-PDM/data/zonas_goiania.csv')

zonas_info = zonas_info[['ZONA', 'LOCAL DE VOTACAO', 'ENDEREÇO', 'BAIRRO']]

# Aplica a transformação em todas as colunas de tipo string
for col in zonas_info.select_dtypes(include=["object"]).columns:
    zonas_info[col] = zonas_info[col].apply(transformar_string)
zonas_info
# Out:
#      ZONA                                   LOCAL DE VOTACAO  \
# 0       1        COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA
# 1     147                                    COLEGIO DESAFIO
# 2     136                   COLEGIO ESTADUAL JARDIM VILA BOA
# 3     127                        ESCOLA SESI JARDIM PLANALTO
# 4     127   COLEGIO ESTADUAL POLIVALENTE PROFO GOIANY PRATES
# ..    ...                                                ...
# 351   134  ESCOLA MUNICIPAL PROFESSOR SALMON GOMES FIGUEI...
# 352     2                       UNIALFA - UNIDADE PERIMETRAL
# 353   127                                    COLEGIO DEGRAUS
# 354   147                      ESCOLA MUNICIPAL ALTO DO VALE
# 355   133  ESCOLA MUNICIPAL PROFESSORA AMELIA FERNANDES M...
#
#                                          ENDEREÇO               BAIRRO
# 0                           AV K, 108 - UNIDADE I      SETOR AEROPORTO
# 1                          AV MANGALO QD 55 LT 06  SETOR MORADA DO SOL
# 2                            RUA PAOLA NEY QD. 59      JARDIM VILA BOA
# 3                          PRACA ITAPUA QD 30 150      JARDIM PLANALTO
# 4                             RUA C-68 QD 115 336      VILAS DOS ALPES
# ..                                            ...                  ...
# 351                RUA SAO DOMINGOS QD. 91 LT. 04   JARDIM PETROPOLIS
# 352                      AV PERIMETRAL NORTE 4129     SETOR GOIANIA II
# 353                                 RUA U-79A, 25          VILA UNIAO
# 354  RUA SAMIR HELOU COM RUA VF 15, QD. 6, LT. 19  SETOR ALTO DO VALE
# 355                                RUA OCANAN, 50     PARQUE ACALANTO
#
# [356 rows x 4 columns]

# %%
zonas_info["ZONA"].unique()
# Out:
# array([  1, 147, 136, 127,   2, 135, 134, 146, 133])

# %%
tse['NR_ZONA'] = tse['NR_ZONA'].astype(int)
zonas_info['ZONA'] = zonas_info['ZONA'].astype(int)

# %%
# Agrupar zonas_info pela coluna ZONA, garantindo que nenhuma informação seja perdida
zonas_info_agrupado = zonas_info.groupby("ZONA").agg({
    "LOCAL DE VOTACAO": lambda x: list(x),
    "ENDEREÇO": lambda x: list(x),
    "BAIRRO": lambda x: list(x)
}).reset_index()

# %%
zonas_info_agrupado
# Out:
#    ZONA                                   LOCAL DE VOTACAO  \
# 0     1  [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# 1     2  [CENTRO DE ENSINO EM PERIODO INTEGRAL AECIO OL...
# 2   127  [ESCOLA SESI JARDIM PLANALTO, COLEGIO ESTADUAL...
# 3   133  [COLEGIO DINAMICO, COLEGIO MARISTA, CENTRO DE ...
# 4   134  [UNIGOIAS - CENTRO UNIVERSITARIO DE GOIAS, COL...
# 5   135  [COLEGIO ESTADUAL IRMA GABRIELA, ESCOLA MUNICI...
# 6   136  [COLEGIO ESTADUAL JARDIM VILA BOA, COLEGIO MUN...
# 7   146  [CEPMGO WALDEMAR MUNDIM, CEPMGO JARDIM GUANABA...
# 8   147  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
#
#                                             ENDEREÇO  \
# 0  [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# 1  [RUA CARIJOS COM RUA DO PRATA, AV SOL NASCENTE...
# 2  [PRACA ITAPUA QD 30 150, RUA C-68 QD 115 336, ...
# 3  [RUA T-37 2693, AVENIDA 85, 1440, RUA 1016, 42...
# 4  [AV. JOAO CANDIDO DE OLIVEIRA, 115, AV FREI CO...
# 5  [RUA PLANALTO, AV. CRISTOVAO COLOMBO, 539, PRA...
# 6  [RUA PAOLA NEY QD. 59, RUA B-16 101, RUA 3 B Q...
# 7  [RUA R-40 QD40 LT07, ALAMEDA MINAS GERAIS QD.7...
# 8  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
#
#                                               BAIRRO
# 0  [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# 1  [SETOR URIAS MAGALHAES, JARDIM NOVA ESPERANCA,...
# 2  [JARDIM PLANALTO, VILAS DOS ALPES, JARDIM AMER...
# 3  [SETOR BUENO, SETOR MARISTA, SETOR PEDRO LUDOV...
# 4  [CIDADE JARDIM, CONJUNTO VERA CRUZ, SAO FRANCI...
# 5  [CONJUNTO RIVIERA, JARDIM NOVO MUNDO, JARDIM N...
# 6  [JARDIM VILA BOA, VILA NOVO HORIZONTE, SETOR G...
# 7  [VILA ITATIAIA, JARDIM GUANABARA, LESTE VILA N...
# 8  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...

# %%
# Realizar a junção das tabelas usando colunas com nomes diferentes
tse_unificado = pd.merge(
    tse, 
    zonas_info_agrupado, 
    left_on="NR_ZONA",  # Coluna na tabela tse
    right_on="ZONA", # Coluna na tabela zonas_info
    how="left"       # Manter todas as linhas de tse
)

# Remover a duplicata da coluna Zona, se necessário
tse_unificado.drop(columns=["ZONA"], inplace=True)

# Visualizar o resultado
tse_unificado
# Out:
#         ANO_ELEICAO NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  \
# 0              2012      GOIANIA        1         1                2
# 1              2012      GOIANIA        1         1                2
# 2              2012      GOIANIA        1         1                2
# 3              2012      GOIANIA        1         1                2
# 4              2012      GOIANIA        1         1                2
# ...             ...          ...      ...       ...              ...
# 285220         2012      GOIANIA      147       451                2
# 285221         2012      GOIANIA      147       451                2
# 285222         2012      GOIANIA      147       451                2
# 285223         2012      GOIANIA      147       451                2
# 285224         2012      GOIANIA      147       451                2
#
#         NR_TURNO  DS_CARGO                        NM_VOTAVEL  QT_VOTOS  \
# 0              1  VEREADOR              ADAILA LUZ PAES LEME         1
# 1              1  VEREADOR  ADRIANA RODRIGUES PINHEIRO DIOGO         1
# 2              1  VEREADOR       ADRIANO RODRIGO LINO MALTEZ         3
# 3              1  VEREADOR       AGNALDO BURJACK EVANGELISTA         1
# 4              1  VEREADOR           AILMA MARIA DE OLIVEIRA         3
# ...          ...       ...                               ...       ...
# 285220         1  VEREADOR                       VOTO BRANCO        21
# 285221         1  VEREADOR                         VOTO NULO        20
# 285222         1  VEREADOR          WALDEMIR SOARES DA SILVA         3
# 285223         1  VEREADOR           WELINGTON PEIXOTO MOURA         3
# 285224         1  VEREADOR       ZANDER FABIO ALVES DA COSTA         1
#
#                                          LOCAL DE VOTACAO  \
# 0       [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# 1       [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# 2       [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# 3       [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# 4       [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# ...                                                   ...
# 285220  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
# 285221  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
# 285222  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
# 285223  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
# 285224  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
#
#                                                  ENDEREÇO  \
# 0       [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# 1       [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# 2       [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# 3       [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# 4       [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# ...                                                   ...
# 285220  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
# 285221  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
# 285222  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
# 285223  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
# 285224  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
#
#                                                    BAIRRO
# 0       [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# 1       [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# 2       [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# 3       [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# 4       [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# ...                                                   ...
# 285220  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...
# 285221  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...
# 285222  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...
# 285223  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...
# 285224  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...
#
# [285225 rows x 12 columns]

# %%
tse_unificado.to_csv("../data/silver/tse_bairros.csv")

# %%
tse.shape
# Out:
# (285225, 9)

# %%
print(tse_unificado.isnull().sum())
# Out:
# ANO_ELEICAO             0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# NR_SECAO                0
# CD_TIPO_ELEICAO         0
# NR_TURNO                0
# DS_CARGO                0
# NM_VOTAVEL              0
# QT_VOTOS                0
# LOCAL DE VOTACAO    12192
# ENDEREÇO            12192
# BAIRRO              12192
# dtype: int64

# %%
tse_unificado.shape
# Out:
# (285225, 12)
