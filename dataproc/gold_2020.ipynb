# %%
import pandas as pd 

agrega = pd.read_csv('gs://trabalho-final-pdm/silver/agregados_2020.csv', storage_options={"token": "google_default"})
# Preparação: adicionar uma coluna de renda média (V005 + V009)
agrega['RENDA'] = agrega['V005'] + agrega['V009']

# %%
# 1. NR_VOTAVEL com maior número de votos por Nome_do_subdistrito
# 2. NM_VOTAVEL com maior número de votos por Nome_do_subdistrito
nr_votavel_subdistrito = agrega.groupby(['Nome_do_subdistrito', 'NR_VOTAVEL', 'NM_VOTAVEL', 'Proporcao_negros_pardos_indigenas', 'Proporcao_feminino', 'Proporcao_18_39'])['QT_VOTOS'].sum().reset_index()
nr_votavel_max = nr_votavel_subdistrito.loc[nr_votavel_subdistrito.groupby('Nome_do_subdistrito')['QT_VOTOS'].idxmax()]

# Partidos políticos mais bem votados por bairro
# Candidato com maior numero de votos por bairro
nr_votavel_max.sort_values('QT_VOTOS')
# Out:
#                                      Nome_do_subdistrito  NR_VOTAVEL  \
# 10902                              U.T.P. JARDIM AMERICA          96
# 22002                            U.T.P. PARQUE BOM JESUS       15602
# 31914                                  U.T.P. VILA RIZZO          95
# 32156                                          VILA RICA       51633
# 625                     U.T.P. ALTO DA GLORIA E REDENCAO          96
# 19569                           U.T.P. NORTE FERROVIARIO       45234
# 7743                         U.T.P. CHACARAS SAO JOAQUIM          96
# 28362                             U.T.P. URIAS MAGALHAES          96
# 6470         U.T.P. CELINA PARK/RECREIO DOS FUNCIONARIOS          96
# 24842                         U.T.P. RIVIERA/AGUA BRANCA       19156
# 2856                                     U.T.P. CAMPINAS          96
# 8054                                U.T.P. CIDADE JARDIM          95
# 10459                                         U.T.P. JAO          96
# 25489                              U.T.P. SANTA GENOVEVA       55191
# 14743                           U.T.P. JARDIM PETROPOLIS          96
# 17075                             U.T.P. MARECHAL RONDON          96
# 27211                                    U.T.P. SUDOESTE          96
# 8597                                      U.T.P. COIMBRA          96
# 18786                              U.T.P. NEGRAO DE LIMA          96
# 17622                                     U.T.P. MARISTA          95
# 25571                               U.T.P. SANTO ANTONIO          95
# 27797                                         U.T.P. SUL          96
# 15626                                   U.T.P. JOAO BRAZ          96
# 29                                      U.T.P. AEROPORTO          96
# 26204                               U.T.P. SANTO HILARIO          96
# 18148                          U.T.P. MUTIRAO E CURITIBA          96
# 23249                           U.T.P. PARQUE SANTA RITA          96
# 31638  U.T.P. VILA REGINA/PARQUE INDUSTRIAL PAULISTA/...       28000
# 19668                  U.T.P. NOVO HORIZONTE/FAICALVILLE          96
# 1977                                U.T.P. BALIZA-ITAIPU       43123
# 12592                                U.T.P. JARDIM GOIAS          95
# 9889                                   U.T.P. GOIANIA II       10100
# 31179                                U.T.P. VILA PEDROSO       36456
# 28766                                   U.T.P. VERA CRUZ          96
# 29775  U.T.P. VILA JARDIM SAO JUDAS TADEU/JARDIM POMPEIA       70123
# 27128                                U.T.P. SAO DOMINGOS       70115
# 5394                                      U.T.P. CAPUAVA       45200
# 22940                     U.T.P. PARQUE OESTE INDUSTRIAL       27456
# 23826                             VOTO BRANCO
# 21266                 CARLOS ALBERTO DA SILVA
# 29849                               VOTO NULO
# 13243             NOVANDIR RODRIGUES DA SILVA
#
#        Proporcao_negros_pardos_indigenas  Proporcao_feminino  Proporcao_18_39  \
# 10902                           0.426829            0.493902         0.225610
# 22002                           0.709369            0.534417         0.216061
# 31914                           0.591331            0.513932         0.286378
# 32156                           0.626374            0.520879         0.219780
# 625                             0.257403            0.544419         0.280182
# 19569                           0.363225            0.557971         0.214674
# 7743                            0.681941            0.536388         0.231806
# 28362                           0.537513            0.532374         0.221994
# 6470                            0.470650            0.519916         0.227463
# 24842                           0.473190            0.564343         0.199732
# 2856                            0.434524            0.517857         0.273810
# 8054                            0.411842            0.492105         0.226316
# 10459                           0.321700            0.502276         0.206373
# 25489                           0.453147            0.520280         0.206993
# 14743                           0.534562            0.529954         0.239631
# 17075                           0.516279            0.522481         0.206202
# 27211                           0.431330            0.497854         0.231760
# 8597                            0.165548            0.536913         0.201342
# 18786                           0.399217            0.526419         0.262231
# 17622                           0.191388            0.545455         0.138756
# 25571                           0.499132            0.501736         0.247396
# 27797                           0.225979            0.585409         0.179715
# 15626                           0.554585            0.499272         0.257642
# 29                              0.227723            0.542574         0.200000
# 26204                           0.669983            0.510779         0.260365
# 18148                           0.603043            0.503458         0.258645
# 23249                           0.614980            0.536137         0.202365
# 31638                           0.568110            0.525871         0.241816
# 19668                           0.438134            0.539554         0.196755
# 1977                            0.715867            0.511685         0.238622
# 12592                           0.549383            0.526749         0.224280
# 9889                            0.416667            0.458333         0.291667
# 31179                           0.634799            0.491396         0.260038
# 28766                           0.573515            0.497566         0.198637
# 29775                           0.512048            0.544177         0.225904
# 27128                           0.696139            0.514321         0.256538
# 5394                            0.598463            0.513929         0.235351
# 22940                           0.539514            0.521277         0.229483
# 4213                            0.544402            0.515444         0.256757
# 20318                           0.154179            0.609510         0.148415
# 22314                           0.766187            0.566547         0.203237
# 15464                           0.674487            0.494135         0.256598
# 11083                           0.508475            0.541314         0.229873
# 11787                           0.456779            0.555050         0.207461
# 2118                            0.411157            0.555785         0.216942
# 16252                           0.406308            0.508349         0.257885
# 3403                            0.450839            0.503597         0.253397
# 9626                            0.658341            0.505798         0.275647
# 1533                            0.389021            0.527446         0.193317
# 6895                            0.441964            0.543155         0.245536
# 13976                           0.582496            0.529412         0.213773
# 5548                            0.158405            0.513390         0.156695
# 23826                           0.403614            0.565060         0.236145
# 21266                           0.540136            0.521088         0.236735
# 29849                           0.338078            0.560498         0.218861
# 13243                           0.533489            0.525701         0.214953
#
#        QT_VOTOS
# 10902        20
# 22002        23
# 31914        29
# 32156        59
# 625          63
# 19569        82
# 7743         91
# 28362       107
# 6470        131
# 24842       138
# 2856        140
# 8054        166
# 10459       179
# 25489       185
# 14743       198
# 17075       198
# 27211       230
# 8597        232
# 18786       240
# 17622       244
# 25571       259
# 27797       281
# 15626       290
# 29          306
# 26204       314
# 18148       335
# 23249       343
# 31638       354
# 19668       363
# 1977        399
# 12592       404
# 9889        425
# 31179       451
# 28766       461
# 29775       467
# 27128       482
# 5394        485
# 22940       502
# 4213        522
# 20318       558
# 22314       613
# 15464       638
# 11083       689
# 11787       714
# 2118        727
# 16252       783
# 3403        801
# 9626        913
# 1533        976
# 6895       1073
# 13976      1239
# 5548       1279
# 23826      1693
# 21266      2095
# 29849      2780
# 13243      3334

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-bairro-2020"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(nr_votavel_max, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-bairro-2020 exportada com sucesso!

# %%
# 3. NM_VOTAVEL com maior número de votos por renda
# 4. NR_VOTAVEL com maior número de votos por renda
# Ordenar por renda para pegar as rendas mais altas e baixas
nm_votavel_renda = agrega.groupby(['RENDA','NR_VOTAVEL','NM_VOTAVEL', 'Proporcao_negros_pardos_indigenas', 'Proporcao_feminino', 'Proporcao_18_39'])['QT_VOTOS'].sum().reset_index()
renda_sorted = nm_votavel_renda.sort_values(by='RENDA')

# Candidato e partido com maior quantidade de votos por renda (renda baixa e alta)
renda_sorted
# Out:
#           RENDA  NR_VOTAVEL                       NM_VOTAVEL  \
# 0       1070.39          11                    PROGRESSISTAS
# 33      1070.39       28008    MAURICIO COSTA DE MOURA FILHO
# 34      1070.39       28444                  MARCELO CONRADO
# 35      1070.39       35353             RANDER GOMES DE DEUS
# 36      1070.39       35700               EDGAR DUARTE GOMES
# ...         ...         ...                              ...
# 32154  17065.38       90500                 TELEMACO BRANDAO
# 32153  17065.38       90444           EDMARCUS CARDOSO SILVA
# 32101  17065.38       70789          JAIME MONTEIRO DA SILVA
# 32149  17065.38       90317  ENI PEREIRA DOS SANTOS MENDONCA
# 32034  17065.38       55900              PEDRO JOSE DA SILVA
#
#        Proporcao_negros_pardos_indigenas  Proporcao_feminino  Proporcao_18_39  \
# 0                               0.626374            0.520879         0.219780
# 33                              0.626374            0.520879         0.219780
# 34                              0.626374            0.520879         0.219780
# 35                              0.626374            0.520879         0.219780
# 36                              0.626374            0.520879         0.219780
# ...                                  ...                 ...              ...
# 32154                           0.158405            0.513390         0.156695
# 32153                           0.158405            0.513390         0.156695
# 32101                           0.158405            0.513390         0.156695
# 32149                           0.158405            0.513390         0.156695
# 32034                           0.158405            0.513390         0.156695
#
#        QT_VOTOS
# 0             1
# 33            3
# 34            1
# 35            1
# 36            2
# ...         ...
# 32154        71
# 32153         5
# 32101        29
# 32149         2
# 32034         5
#
# [32161 rows x 7 columns]

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-renda-2020"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(renda_sorted, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-renda-2020 exportada com sucesso!
