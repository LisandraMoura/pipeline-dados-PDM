# %%
import pandas as pd 

agrega = pd.read_csv('gs://trabalho-final-pdm/silver/agregados_2020.csv', storage_options={"token": "google_default"})
# Preparação: adicionar uma coluna de renda média (V005 + V009)
agrega['RENDA'] = agrega['V005'] + agrega['V009']

# %%
# 1. NR_VOTAVEL com maior número de votos por Nome_do_subdistrito
# 2. NM_VOTAVEL com maior número de votos por Nome_do_subdistrito
nr_votavel_subdistrito = agrega.groupby(['Nome_do_subdistrito', 'NR_VOTAVEL', 'NM_VOTAVEL'])['QT_VOTOS'].sum().reset_index()
nr_votavel_max = nr_votavel_subdistrito.loc[nr_votavel_subdistrito.groupby('Nome_do_subdistrito')['QT_VOTOS'].idxmax()]

# Partidos políticos mais bem votados por bairro
# Candidato com maior numero de votos por bairro
nr_votavel_max.sort_values('QT_VOTOS')
# Out:
#                                      Nome_do_subdistrito  NR_VOTAVEL  \
# 10902                              U.T.P. JARDIM AMERICA          96
# 22002                            U.T.P. PARQUE BOM JESUS       15602
# 31914                                  U.T.P. VILA RIZZO          95
# 32156                                          VILA RICA       51633
# 625                     U.T.P. ALTO DA GLORIA E REDENCAO          96
# 19569                           U.T.P. NORTE FERROVIARIO       45234
# 7743                         U.T.P. CHACARAS SAO JOAQUIM          96
# 28362                             U.T.P. URIAS MAGALHAES          96
# 6470         U.T.P. CELINA PARK/RECREIO DOS FUNCIONARIOS          96
# 24842                         U.T.P. RIVIERA/AGUA BRANCA       19156
# 2856                                     U.T.P. CAMPINAS          96
# 8054                                U.T.P. CIDADE JARDIM          95
# 10459                                         U.T.P. JAO          96
# 25489                              U.T.P. SANTA GENOVEVA       55191
# 14743                           U.T.P. JARDIM PETROPOLIS          96
# 17075                             U.T.P. MARECHAL RONDON          96
# 27211                                    U.T.P. SUDOESTE          96
# 8597                                      U.T.P. COIMBRA          96
# 18786                              U.T.P. NEGRAO DE LIMA          96
# 17622                                     U.T.P. MARISTA          95
# 25571                               U.T.P. SANTO ANTONIO          95
# 27797                                         U.T.P. SUL          96
# 15626                                   U.T.P. JOAO BRAZ          96
# 29                                      U.T.P. AEROPORTO          96
# 26204                               U.T.P. SANTO HILARIO          96
# 18148                          U.T.P. MUTIRAO E CURITIBA          96
# 23249                           U.T.P. PARQUE SANTA RITA          96
# 31638  U.T.P. VILA REGINA/PARQUE INDUSTRIAL PAULISTA/...       28000
# 19668                  U.T.P. NOVO HORIZONTE/FAICALVILLE          96
# 1977                                U.T.P. BALIZA-ITAIPU       43123
# 12592                                U.T.P. JARDIM GOIAS          95
# 9889                                   U.T.P. GOIANIA II       10100
# 31179                                U.T.P. VILA PEDROSO       36456
# 28766                                   U.T.P. VERA CRUZ          96
# 29775  U.T.P. VILA JARDIM SAO JUDAS TADEU/JARDIM POMPEIA       70123
# 27128                                U.T.P. SAO DOMINGOS       70115
# 5394                                      U.T.P. CAPUAVA       45200
# 22940                     U.T.P. PARQUE OESTE INDUSTRIAL       27456
# 4213                U.T.P. CANDIDA DE MORAIS/MARIA DILCE          96
# 20318                                       U.T.P. OESTE          96
# 22314      U.T.P. PARQUE DAS LARANJEIRAS E JARDIM DA LUZ       23123
# 15464      U.T.P. JARDIM PRIMAVERA (AREA URBANA ISOLADA)       35233
# 11083  U.T.P. JARDIM BALNEARIO MEIA PONTE/MANSOES GOI...          96
# 11787                               U.T.P. JARDIM EUROPA          96
# 2118                                        U.T.P. BUENO          96
# 16252                         U.T.P. LESTE UNIVERSITARIO          96
# 3403       U.T.P. CAMPUS UNIVERSITARIO/CONJUNTO ITATIAIA          96
# 9626                                    U.T.P. FINSOCIAL       36007
# 1533                                 U.T.P. BAIRRO FELIZ       51456
# 6895                                      U.T.P. CENTRAL          96
# 13976                           U.T.P. JARDIM NOVO MUNDO       10456
# 5548                         U.T.P. CEASA/ALDEIA DO VALE          96
# 23826  U.T.P. PEDRO LUDOVICO/BELA VISTA/JARDINS DAS E...          95
# 21266                             U.T.P. PARQUE AMAZONIA       15273
# 29849                                   U.T.P. VILA NOVA          96
# 13243                            U.T.P. JARDIM GUANABARA       10100
#
#                                    NM_VOTAVEL  QT_VOTOS
# 10902                               VOTO NULO        20
# 22002       ANSELMO PEREIRA DA SILVA SOBRINHO        23
# 31914                             VOTO BRANCO        29
# 32156           ALFREDO DA ROCHA ARAUJO FILHO        59
# 625                                 VOTO NULO        63
# 19569  ALESSANDRO PEREIRA DOS SANTOS VITORINO        82
# 7743                                VOTO NULO        91
# 28362                               VOTO NULO       107
# 6470                                VOTO NULO       131
# 24842                  RONNY DE SOUZA ESTEVES       138
# 2856                                VOTO NULO       140
# 8054                              VOTO BRANCO       166
# 10459                               VOTO NULO       179
# 25489                     NEWTON MORAIS SOUZA       185
# 14743                               VOTO NULO       198
# 17075                               VOTO NULO       198
# 27211                               VOTO NULO       230
# 8597                                VOTO NULO       232
# 18786                               VOTO NULO       240
# 17622                             VOTO BRANCO       244
# 25571                             VOTO BRANCO       259
# 27797                               VOTO NULO       281
# 15626                               VOTO NULO       290
# 29                                  VOTO NULO       306
# 26204                               VOTO NULO       314
# 18148                               VOTO NULO       335
# 23249                               VOTO NULO       343
# 31638                ALZIRO DE CASTRO MIRANDA       354
# 19668                               VOTO NULO       363
# 1977              CARLOS SILVA DE SOUSA ALVES       399
# 12592                             VOTO BRANCO       404
# 9889              NOVANDIR RODRIGUES DA SILVA       425
# 31179        GENIVALDO DE SOUZA DILL OLIVEIRA       451
# 28766                               VOTO NULO       461
# 29775            GEVERSON ABEL DE SOUZA CARMO       467
# 27128            MIGUEL VELOSO DA SILVA FILHO       482
# 5394                 WILLIAM TAVARES DA SILVA       485
# 22940                 MARCIO ANTONIO DO CARMO       502
# 4213                                VOTO NULO       522
# 20318                               VOTO NULO       558
# 22314              MARLON DOS SANTOS TEIXEIRA       613
# 15464                CLEZER DE OLIVEIRA PINTO       638
# 11083                               VOTO NULO       689
# 11787                               VOTO NULO       714
# 2118                                VOTO NULO       727
# 16252                               VOTO NULO       783
# 3403                                VOTO NULO       801
# 9626                      EUDES CARDOSO ALVES       913
# 1533                  MARCOS ANTONIO DA SILVA       976
# 6895                                VOTO NULO      1073
# 13976                 NILTON PEREIRA DA SILVA      1239
# 5548                                VOTO NULO      1279
# 23826                             VOTO BRANCO      1693
# 21266                 CARLOS ALBERTO DA SILVA      2095
# 29849                               VOTO NULO      2780
# 13243             NOVANDIR RODRIGUES DA SILVA      3334

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-bairro-2020"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(nr_votavel_max, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-bairro-2020 exportada com sucesso!

# %%
# 3. NM_VOTAVEL com maior número de votos por renda
# 4. NR_VOTAVEL com maior número de votos por renda
# Ordenar por renda para pegar as rendas mais altas e baixas
nm_votavel_renda = agrega.groupby(['RENDA','NR_VOTAVEL','NM_VOTAVEL'])['QT_VOTOS'].sum().reset_index()
renda_sorted = nm_votavel_renda.sort_values(by='RENDA')

# Candidato e partido com maior quantidade de votos por renda (renda baixa e alta)
renda_sorted
# Out:
#           RENDA  NR_VOTAVEL                       NM_VOTAVEL  QT_VOTOS
# 0       1070.39          11                    PROGRESSISTAS         1
# 33      1070.39       28008    MAURICIO COSTA DE MOURA FILHO         3
# 34      1070.39       28444                  MARCELO CONRADO         1
# 35      1070.39       35353             RANDER GOMES DE DEUS         1
# 36      1070.39       35700               EDGAR DUARTE GOMES         2
# ...         ...         ...                              ...       ...
# 32154  17065.38       90500                 TELEMACO BRANDAO        71
# 32153  17065.38       90444           EDMARCUS CARDOSO SILVA         5
# 32101  17065.38       70789          JAIME MONTEIRO DA SILVA        29
# 32149  17065.38       90317  ENI PEREIRA DOS SANTOS MENDONCA         2
# 32034  17065.38       55900              PEDRO JOSE DA SILVA         5
#
# [32161 rows x 4 columns]

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-renda-2020"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(nr_votavel_max, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-renda-2020 exportada com sucesso!
