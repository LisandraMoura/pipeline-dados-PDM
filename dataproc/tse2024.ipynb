# %%
import pandas as pd

# Caminho do arquivo no GCS
gcs_path = "gs://trabalho-final-pdm/bronze/votacao_secao_2024_GO"

# Ler o arquivo diretamente usando pandas e gcsfs
tse = pd.read_csv(gcs_path, encoding='Latin-1', sep=';', storage_options={"token": "google_default"})
tse.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  28/10/2024   11:46:22         2024                2  Eleição Ordinária
# 1  28/10/2024   11:46:22         2024                2  Eleição Ordinária
# 2  28/10/2024   11:46:22         2024                2  Eleição Ordinária
# 3  28/10/2024   11:46:22         2024                2  Eleição Ordinária
# 4  28/10/2024   11:46:22         2024                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         619  Eleições Municipais 2024  06/10/2024              M
# 1         1         619  Eleições Municipais 2024  06/10/2024              M
# 2         1         619  Eleições Municipais 2024  06/10/2024              M
# 3         1         619  Eleições Municipais 2024  06/10/2024              M
# 4         1         619  Eleições Municipais 2024  06/10/2024              M
#
#    ... NR_SECAO  CD_CARGO  DS_CARGO  NR_VOTAVEL  \
# 0  ...       22        13  Vereador       11111
# 1  ...       89        13  Vereador       27000
# 2  ...      244        13  Vereador       22522
# 3  ...      125        13  Vereador       45789
# 4  ...      244        13  Vereador       45789
#
#                         NM_VOTAVEL  QT_VOTOS  NR_LOCAL_VOTACAO  SQ_CANDIDATO  \
# 0  VALMI BARBOSA DOS SANTOS JUNIOR         6              1066   90002060888
# 1    ANISIO VICENTE FERREIRA FILHO         1              1015   90002182962
# 2                  ALINE FERNANDES         3              1333   90002066094
# 3        ISMAEL FRANCISCO DE ASSIS         1              1279   90002050063
# 4        ISMAEL FRANCISCO DE ASSIS         4              1333   90002050063
#
#                                     NM_LOCAL_VOTACAO  \
# 0                      COLÉGIO ESTADUAL DR NEGREIROS
# 1  CENTRO DE ENSINO EM PERÍODO INTEGRAL JOSÉ SALV...
# 2                    ESCOLA MUNICIPAL LAURO DA PENHA
# 3            ESCOLA MUNICIPAL PROFESSOR JUDITH LEITE
# 4                    ESCOLA MUNICIPAL LAURO DA PENHA
#
#             DS_LOCAL_VOTACAO_ENDERECO
# 0       RUA NARCEU DE ALMEIDA  N. 220
# 1  RUA JACINTO FERREIRA DE SOUZA, 950
# 2                RUA ANDORINHA, N 466
# 3                        RUA 20 N 597
# 4                RUA ANDORINHA, N 466
#
# [5 rows x 26 columns]

# %%
# features importantes
print(tse.columns)
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'NR_ZONA', 'NR_SECAO', 'CD_CARGO', 'DS_CARGO',
#        'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_LOCAL_VOTACAO',
#        'SQ_CANDIDATO', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO'],
#       dtype='object')

# %%
# alguns dados foram incluidos a partir de 2016
tse['DS_LOCAL_VOTACAO_ENDERECO']
# Out:
# 0                      RUA NARCEU DE ALMEIDA  N. 220
# 1                 RUA JACINTO FERREIRA DE SOUZA, 950
# 2                               RUA ANDORINHA, N 466
# 3                                       RUA 20 N 597
# 4                               RUA ANDORINHA, N 466
#                              ...
# 1320307                    AV. TEODORO SAMPAIO NR 23
# 1320308    RUA MANOEL SILVA  QD 08 LT 01 VILA REGINA
# 1320309          RUA CARIJOS ESQ C/ RUA DO PRATA S/N
# 1320310      R.ESTRADA DUQUE DE CAXIAS QD 3 LT 48/49
# 1320311             RUA 3 B QD 51 S/N - GARAVELO - B
# Name: DS_LOCAL_VOTACAO_ENDERECO, Length: 1320312, dtype: object

# %%
tse = tse[['ANO_ELEICAO','NM_MUNICIPIO','NR_ZONA', 'NR_SECAO', 'CD_TIPO_ELEICAO','NR_TURNO', 'DS_CARGO', 'NM_VOTAVEL', 'NR_VOTAVEL', 'QT_VOTOS', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO']]

# %%
from unidecode import unidecode

# transformações nos dados
# 
# Função para transformar texto: remover acentos e deixar em maiúsculas
def transformar_string(valor):
    if isinstance(valor, str):  # Verifica se é uma string
        return unidecode(valor).upper()
    return valor  # Retorna o valor original se não for string

# Aplica a transformação em todas as colunas de tipo string
for col in tse.select_dtypes(include=["object"]).columns:
    tse[col] = tse[col].apply(transformar_string)

tse
# Out:
#          ANO_ELEICAO           NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 0               2024              NEROPOLIS       54        22
# 1               2024  SANTA HELENA DE GOIAS       66        89
# 2               2024              GOIANESIA       74       244
# 3               2024              GOIANESIA       74       125
# 4               2024              GOIANESIA       74       244
# ...              ...                    ...      ...       ...
# 1320307         2024                IPAMERI       14        35
# 1320308         2024                GOIANIA      147        31
# 1320309         2024                GOIANIA        2       367
# 1320310         2024                GOIANIA      136       362
# 1320311         2024                GOIANIA      136       310
#
#          CD_TIPO_ELEICAO  NR_TURNO  DS_CARGO                       NM_VOTAVEL  \
# 0                      2         1  VEREADOR  VALMI BARBOSA DOS SANTOS JUNIOR
# 1                      2         1  VEREADOR    ANISIO VICENTE FERREIRA FILHO
# 2                      2         1  VEREADOR                  ALINE FERNANDES
# 3                      2         1  VEREADOR        ISMAEL FRANCISCO DE ASSIS
# 4                      2         1  VEREADOR        ISMAEL FRANCISCO DE ASSIS
# ...                  ...       ...       ...                              ...
# 1320307                2         1  VEREADOR           CLEBERSON ANTONIO LUIZ
# 1320308                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
# 1320309                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
# 1320310                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
# 1320311                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
#
#          NR_VOTAVEL  QT_VOTOS  \
# 0             11111         6
# 1             27000         1
# 2             22522         3
# 3             45789         1
# 4             45789         4
# ...             ...       ...
# 1320307       55123         3
# 1320308       25456         1
# 1320309       25456         2
# 1320310       25456         1
# 1320311       25456         1
#
#                                           NM_LOCAL_VOTACAO  \
# 0                            COLEGIO ESTADUAL DR NEGREIROS
# 1        CENTRO DE ENSINO EM PERIODO INTEGRAL JOSE SALV...
# 2                          ESCOLA MUNICIPAL LAURO DA PENHA
# 3                  ESCOLA MUNICIPAL PROFESSOR JUDITH LEITE
# 4                          ESCOLA MUNICIPAL LAURO DA PENHA
# ...                                                    ...
# 1320307                  ESCOLA ESTADUAL MICHELE SANTINONI
# 1320308            ESCOLA MUNICIPAL PEDRO GOMES DE MENEZES
# 1320309  CENTRO DE ENSINO EM PERIODO INTEGRAL AECIO OLI...
# 1320310          ESCOLA GOVERNADOR JOAQUIM SOBROSA - LIONS
# 1320311                       COLEGIO ESTADUAL VILLA LOBOS
#
#                          DS_LOCAL_VOTACAO_ENDERECO
# 0                    RUA NARCEU DE ALMEIDA  N. 220
# 1               RUA JACINTO FERREIRA DE SOUZA, 950
# 2                             RUA ANDORINHA, N 466
# 3                                     RUA 20 N 597
# 4                             RUA ANDORINHA, N 466
# ...                                            ...
# 1320307                  AV. TEODORO SAMPAIO NR 23
# 1320308  RUA MANOEL SILVA  QD 08 LT 01 VILA REGINA
# 1320309        RUA CARIJOS ESQ C/ RUA DO PRATA S/N
# 1320310    R.ESTRADA DUQUE DE CAXIAS QD 3 LT 48/49
# 1320311           RUA 3 B QD 51 S/N - GARAVELO - B
#
# [1320312 rows x 12 columns]

# %%
print(tse.isnull().sum())
# Out:
# ANO_ELEICAO                  0
# NM_MUNICIPIO                 0
# NR_ZONA                      0
# NR_SECAO                     0
# CD_TIPO_ELEICAO              0
# NR_TURNO                     0
# DS_CARGO                     0
# NM_VOTAVEL                   0
# NR_VOTAVEL                   0
# QT_VOTOS                     0
# NM_LOCAL_VOTACAO             0
# DS_LOCAL_VOTACAO_ENDERECO    0
# dtype: int64

# %%
# filtros

tse['NM_MUNICIPIO'].unique()
# Out:
# array(['NEROPOLIS', 'SANTA HELENA DE GOIAS', 'GOIANESIA', 'NOVO GAMA',
#        'ITAPURANGA', 'MAURILANDIA', 'CATALAO', 'DIVINOPOLIS DE GOIAS',
#        'SAO JOAO D ALIANCA', 'MOZARLANDIA', 'CACHOEIRA ALTA', 'JUSSARA',
#        'ABADIA DE GOIAS', 'NOVO BRASIL', 'TEREZOPOLIS DE GOIAS',
#        'ALTO PARAISO DE GOIAS', 'INACIOLANDIA', 'JANDAIA', 'HIDROLANDIA',
#        'NOVA VENEZA', 'CAIAPONIA', 'CASTELANDIA', 'JESUPOLIS', 'URUACU',
#        'VALPARAISO DE GOIAS', 'SANTA RITA DO ARAGUAIA', 'ISRAELANDIA',
#        'PALMEIRAS DE GOIAS', 'MORRINHOS', 'PIRACANJUBA',
#        'COCALZINHO DE GOIAS', 'URUANA', 'PADRE BERNARDO', 'MUTUNOPOLIS',
#        'NOVO PLANALTO', 'IVOLANDIA', 'MARA ROSA', 'ITAJA', 'NOVA ROMA',
#        'JOVIANIA', 'CERES', 'SANTA BARBARA DE GOIAS', 'RUBIATABA',
#        'FAINA', 'MARZAGAO', 'FORMOSO', 'ITAUCU', 'SITIO D ABADIA',
#        'SANTA TEREZA DE GOIAS', 'PALMELO', 'BURITINOPOLIS',
#        'OURO VERDE DE GOIAS', 'CACHOEIRA DE GOIAS', 'ARAGARCAS',
#        'ORIZONA', 'FORMOSA', 'MINEIROS', 'NIQUELANDIA', 'CRISTALINA',
#        'APARECIDA DO RIO DOCE', 'BALIZA', 'AVELINOPOLIS', 'HEITORAI',
#        'LAGOA SANTA', 'CRISTIANOPOLIS', 'GUARINOS', 'BRITANIA', 'CATURAI',
#        'SAO SIMAO', 'CORREGO DO OURO', 'MONTIVIDIU', 'MOSSAMEDES',
#        'GAMELEIRA DE GOIAS', 'ARAGUAPAZ', 'CORUMBAIBA', 'JARAGUA',
#        'ITARUMA', 'LUZIANIA', 'PIRENOPOLIS', 'PLANALTINA',
#        'AGUAS LINDAS DE GOIAS', 'ALTO HORIZONTE', 'ALVORADA DO NORTE',
#        'SANTA CRUZ DE GOIAS', 'ARUANA', 'VIANOPOLIS', 'CHAPADAO DO CEU',
#        'ARENOPOLIS', 'GOIANDIRA', 'CRIXAS', 'PALESTINA DE GOIAS',
#        'MONTES CLAROS DE GOIAS', 'TROMBAS', 'FIRMINOPOLIS',
#        'TERESINA DE GOIAS', 'HIDROLINA', 'CAMPO ALEGRE DE GOIAS',
#        'JAUPACI', 'BONFINOPOLIS', 'SAO LUIZ DO NORTE', 'SAO PATRICIO',
#        'MUNDO NOVO', 'DIORAMA', 'SAO MIGUEL DO ARAGUAIA', 'NAZARIO',
#        'PORTEIRAO', 'RIO VERDE', 'OUVIDOR', 'GOIATUBA', 'GUAPO',
#        'BOM JESUS DE GOIAS', 'CAMPESTRE DE GOIAS', 'ANICUNS', 'CEZARINA',
#        'VICENTINOPOLIS', 'PONTALINA', 'GOIANAPOLIS', 'CROMINIA',
#        'ITAPIRAPUA', 'SANTO ANTONIO DA BARRA', 'CACU', 'UIRAPURU',
#        'SANCLERLANDIA', 'RIANAPOLIS', 'TURVELANDIA', 'PORTELANDIA',
#        'CUMARI', 'URUTAI', 'FLORES DE GOIAS', 'NOVA GLORIA',
#        'CACHOEIRA DOURADA', 'ITAGUARU', 'ANHANGUERA', 'DOVERLANDIA',
#        'AMARALINA', 'ANAPOLIS', 'SAO LUIS DE MONTES BELOS', 'ARAGOIANIA',
#        'PIRES DO RIO', 'ALEXANIA', 'CALDAS NOVAS', 'ABADIANIA',
#        'EDEALINA', 'BRAZABRANTES', 'IPIRANGA DE GOIAS', 'AURILANDIA',
#        'VILA BOA', 'DAMOLANDIA', 'MIMOSO DE GOIAS', 'QUIRINOPOLIS',
#        'SILVANIA', 'CORUMBA DE GOIAS', 'SAO FRANCISCO DE GOIAS',
#        'PARANAIGUARA', 'SANTA RITA DO NOVO DESTINO', 'SAO DOMINGOS',
#        'CARMO DO RIO VERDE', 'PALMINOPOLIS', 'TURVANIA',
#        'APARECIDA DE GOIANIA', 'ITUMBIARA', 'GOIAS', 'RIALMA',
#        'LEOPOLDO DE BULHOES', 'NOVA CRIXAS', 'TRINDADE', 'INHUMAS',
#        'JATAI', 'INDIARA', 'SANTA TEREZINHA DE GOIAS', 'DAMIANOPOLIS',
#        'MAIRIPOTABA', 'ITABERAI', 'VILA PROPICIO', 'BOM JARDIM DE GOIAS',
#        'CAMPOS BELOS', 'ITAPACI', 'AGUA FRIA DE GOIAS',
#        'SAO MIGUEL DO PASSA QUATRO', 'SANTO ANTONIO DE GOIAS', 'VARJAO',
#        'BONOPOLIS', 'SIMOLANDIA', 'ITAGUARI', 'MAMBAI',
#        'BELA VISTA DE GOIAS', 'PROFESSOR JAMIL', 'APORE',
#        'PILAR DE GOIAS', 'MORRO AGUDO DE GOIAS', 'IACIARA', 'RIO QUENTE',
#        'SANTA FE DE GOIAS', 'NOVA AMERICA', 'PEROLANDIA', 'AGUA LIMPA',
#        'ALOANDIA', 'CALDAZINHA', 'ESTRELA DO NORTE', 'ADELANDIA',
#        'FAZENDA NOVA', 'NOVA AURORA', 'NOVA IGUACU DE GOIAS',
#        'GOUVELANDIA', 'MATRINCHA', 'SANTA ISABEL', 'GUARAITA',
#        'BURITI DE GOIAS', 'SAO JOAO DA PARAUNA', 'AMORINOPOLIS',
#        'GUARANI DE GOIAS', 'CAMPOS VERDES', 'SERRANOPOLIS',
#        'AMERICANO DO BRASIL', 'CAMPINACU', 'PARAUNA', 'TAQUARAL DE GOIAS',
#        'SENADOR CANEDO', 'BURITI ALEGRE', 'ARACU', 'GOIANIRA',
#        'CABECEIRAS', 'CIDADE OCIDENTAL', 'MINACU', 'GOIANIA', 'IPORA',
#        'SANTO ANTONIO DO DESCOBERTO', 'ACREUNA', 'PETROLINA DE GOIAS',
#        'PANAMA', 'POSSE', 'CAMPINORTE', 'IPAMERI', 'DAVINOPOLIS',
#        'PIRANHAS', 'PORANGATU', 'COLINAS DO SUL', 'EDEIA',
#        'MONTE ALEGRE DE GOIAS', 'BARRO ALTO', 'CAVALCANTE',
#        'CAMPO LIMPO DE GOIAS', 'MOIPORA', 'SANTA ROSA DE GOIAS',
#        'TRES RANCHOS', 'MONTIVIDIU DO NORTE'], dtype=object)

# %%
tse.head()
# Out:
#    ANO_ELEICAO           NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  \
# 0         2024              NEROPOLIS       54        22                2
# 1         2024  SANTA HELENA DE GOIAS       66        89                2
# 2         2024              GOIANESIA       74       244                2
# 3         2024              GOIANESIA       74       125                2
# 4         2024              GOIANESIA       74       244                2
#
#    NR_TURNO  DS_CARGO                       NM_VOTAVEL  NR_VOTAVEL  QT_VOTOS  \
# 0         1  VEREADOR  VALMI BARBOSA DOS SANTOS JUNIOR       11111         6
# 1         1  VEREADOR    ANISIO VICENTE FERREIRA FILHO       27000         1
# 2         1  VEREADOR                  ALINE FERNANDES       22522         3
# 3         1  VEREADOR        ISMAEL FRANCISCO DE ASSIS       45789         1
# 4         1  VEREADOR        ISMAEL FRANCISCO DE ASSIS       45789         4
#
#                                     NM_LOCAL_VOTACAO  \
# 0                      COLEGIO ESTADUAL DR NEGREIROS
# 1  CENTRO DE ENSINO EM PERIODO INTEGRAL JOSE SALV...
# 2                    ESCOLA MUNICIPAL LAURO DA PENHA
# 3            ESCOLA MUNICIPAL PROFESSOR JUDITH LEITE
# 4                    ESCOLA MUNICIPAL LAURO DA PENHA
#
#             DS_LOCAL_VOTACAO_ENDERECO
# 0       RUA NARCEU DE ALMEIDA  N. 220
# 1  RUA JACINTO FERREIRA DE SOUZA, 950
# 2                RUA ANDORINHA, N 466
# 3                        RUA 20 N 597
# 4                RUA ANDORINHA, N 466

# %%
# Agregação com tabela zonas

# Ler o arquivo diretamente usando pandas e gcsfs
zonas_info = pd.read_csv('gs://trabalho-final-pdm/bronze/zonas_goiania', storage_options={"token": "google_default"})

zonas_info = zonas_info[['ZONA', 'LOCAL DE VOTACAO', 'ENDEREÇO', 'BAIRRO']]

# Aplica a transformação em todas as colunas de tipo string
for col in zonas_info.select_dtypes(include=["object"]).columns:
    zonas_info[col] = zonas_info[col].apply(transformar_string)
zonas_info
# Out:
#      ZONA                                   LOCAL DE VOTACAO  \
# 0       1        COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA
# 1     147                                    COLEGIO DESAFIO
# 2     136                   COLEGIO ESTADUAL JARDIM VILA BOA
# 3     127                        ESCOLA SESI JARDIM PLANALTO
# 4     127   COLEGIO ESTADUAL POLIVALENTE PROFO GOIANY PRATES
# ..    ...                                                ...
# 351   134  ESCOLA MUNICIPAL PROFESSOR SALMON GOMES FIGUEI...
# 352     2                       UNIALFA - UNIDADE PERIMETRAL
# 353   127                                    COLEGIO DEGRAUS
# 354   147                      ESCOLA MUNICIPAL ALTO DO VALE
# 355   133  ESCOLA MUNICIPAL PROFESSORA AMELIA FERNANDES M...
#
#                                          ENDEREÇO               BAIRRO
# 0                           AV K, 108 - UNIDADE I      SETOR AEROPORTO
# 1                          AV MANGALO QD 55 LT 06  SETOR MORADA DO SOL
# 2                            RUA PAOLA NEY QD. 59      JARDIM VILA BOA
# 3                          PRACA ITAPUA QD 30 150      JARDIM PLANALTO
# 4                             RUA C-68 QD 115 336      VILAS DOS ALPES
# ..                                            ...                  ...
# 351                RUA SAO DOMINGOS QD. 91 LT. 04   JARDIM PETROPOLIS
# 352                      AV PERIMETRAL NORTE 4129     SETOR GOIANIA II
# 353                                 RUA U-79A, 25          VILA UNIAO
# 354  RUA SAMIR HELOU COM RUA VF 15, QD. 6, LT. 19  SETOR ALTO DO VALE
# 355                                RUA OCANAN, 50     PARQUE ACALANTO
#
# [356 rows x 4 columns]

# %%
tse['NR_ZONA'] = tse['NR_ZONA'].astype(int)
zonas_info['ZONA'] = zonas_info['ZONA'].astype(int)

# %%
# Agrupar zonas_info pela coluna ZONA, garantindo que nenhuma informação seja perdida
zonas_info_agrupado = zonas_info.groupby("ZONA").agg({
    "LOCAL DE VOTACAO": lambda x: list(x),
    "ENDEREÇO": lambda x: list(x),
    "BAIRRO": lambda x: list(x)
}).reset_index()

# %%
# Realizar a junção das tabelas usando colunas com nomes diferentes
tse_unificado = pd.merge(
    tse, 
    zonas_info_agrupado, 
    left_on="NR_ZONA",  # Coluna na tabela tse
    right_on="ZONA", # Coluna na tabela zonas_info
    how="left"       # Manter todas as linhas de tse
)

# Remover a duplicata da coluna Zona, se necessário
tse_unificado.drop(columns=["ZONA"], inplace=True)

# Visualizar o resultado
tse_unificado
# Out:
#          ANO_ELEICAO           NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 0               2024              NEROPOLIS       54        22
# 1               2024  SANTA HELENA DE GOIAS       66        89
# 2               2024              GOIANESIA       74       244
# 3               2024              GOIANESIA       74       125
# 4               2024              GOIANESIA       74       244
# ...              ...                    ...      ...       ...
# 1320307         2024                IPAMERI       14        35
# 1320308         2024                GOIANIA      147        31
# 1320309         2024                GOIANIA        2       367
# 1320310         2024                GOIANIA      136       362
# 1320311         2024                GOIANIA      136       310
#
#          CD_TIPO_ELEICAO  NR_TURNO  DS_CARGO                       NM_VOTAVEL  \
# 0                      2         1  VEREADOR  VALMI BARBOSA DOS SANTOS JUNIOR
# 1                      2         1  VEREADOR    ANISIO VICENTE FERREIRA FILHO
# 2                      2         1  VEREADOR                  ALINE FERNANDES
# 3                      2         1  VEREADOR        ISMAEL FRANCISCO DE ASSIS
# 4                      2         1  VEREADOR        ISMAEL FRANCISCO DE ASSIS
# ...                  ...       ...       ...                              ...
# 1320307                2         1  VEREADOR           CLEBERSON ANTONIO LUIZ
# 1320308                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
# 1320309                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
# 1320310                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
# 1320311                2         1  VEREADOR          MARCOS ANTONIO DA SILVA
#
#          NR_VOTAVEL  QT_VOTOS  \
# 0             11111         6
# 1             27000         1
# 2             22522         3
# 3             45789         1
# 4             45789         4
# ...             ...       ...
# 1320307       55123         3
# 1320308       25456         1
# 1320309       25456         2
# 1320310       25456         1
# 1320311       25456         1
#
#                                           NM_LOCAL_VOTACAO  \
# 0                            COLEGIO ESTADUAL DR NEGREIROS
# 1        CENTRO DE ENSINO EM PERIODO INTEGRAL JOSE SALV...
# 2                          ESCOLA MUNICIPAL LAURO DA PENHA
# 3                  ESCOLA MUNICIPAL PROFESSOR JUDITH LEITE
# 4                          ESCOLA MUNICIPAL LAURO DA PENHA
# ...                                                    ...
# 1320307                  ESCOLA ESTADUAL MICHELE SANTINONI
# 1320308            ESCOLA MUNICIPAL PEDRO GOMES DE MENEZES
# 1320309  CENTRO DE ENSINO EM PERIODO INTEGRAL AECIO OLI...
# 1320310          ESCOLA GOVERNADOR JOAQUIM SOBROSA - LIONS
# 1320311                       COLEGIO ESTADUAL VILLA LOBOS
#
#                          DS_LOCAL_VOTACAO_ENDERECO  \
# 0                    RUA NARCEU DE ALMEIDA  N. 220
# 1               RUA JACINTO FERREIRA DE SOUZA, 950
# 2                             RUA ANDORINHA, N 466
# 3                                     RUA 20 N 597
# 4                             RUA ANDORINHA, N 466
# ...                                            ...
# 1320307                  AV. TEODORO SAMPAIO NR 23
# 1320308  RUA MANOEL SILVA  QD 08 LT 01 VILA REGINA
# 1320309        RUA CARIJOS ESQ C/ RUA DO PRATA S/N
# 1320310    R.ESTRADA DUQUE DE CAXIAS QD 3 LT 48/49
# 1320311           RUA 3 B QD 51 S/N - GARAVELO - B
#
#                                           LOCAL DE VOTACAO  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1320307                                                NaN
# 1320308  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
# 1320309  [CENTRO DE ENSINO EM PERIODO INTEGRAL AECIO OL...
# 1320310  [COLEGIO ESTADUAL JARDIM VILA BOA, COLEGIO MUN...
# 1320311  [COLEGIO ESTADUAL JARDIM VILA BOA, COLEGIO MUN...
#
#                                                   ENDEREÇO  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1320307                                                NaN
# 1320308  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
# 1320309  [RUA CARIJOS COM RUA DO PRATA, AV SOL NASCENTE...
# 1320310  [RUA PAOLA NEY QD. 59, RUA B-16 101, RUA 3 B Q...
# 1320311  [RUA PAOLA NEY QD. 59, RUA B-16 101, RUA 3 B Q...
#
#                                                     BAIRRO
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1320307                                                NaN
# 1320308  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...
# 1320309  [SETOR URIAS MAGALHAES, JARDIM NOVA ESPERANCA,...
# 1320310  [JARDIM VILA BOA, VILA NOVO HORIZONTE, SETOR G...
# 1320311  [JARDIM VILA BOA, VILA NOVO HORIZONTE, SETOR G...
#
# [1320312 rows x 15 columns]

# %%
tse_unificado.shape, tse.shape
# Out:
# ((1320312, 15), (1320312, 12))

# %%
# Salvar DataFrame diretamente no GCS
gcs_path = "gs://trabalho-final-pdm/silver/tse_bairros_2024.csv"

# Escrever para o Cloud Storage usando storage_options
tse_unificado.to_csv(gcs_path, index=False, storage_options={"token": "google_default"})
