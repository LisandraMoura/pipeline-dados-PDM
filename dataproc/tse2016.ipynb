# %%
import pandas as pd

# Caminho do arquivo no GCS
gcs_path = "gs://trabalho-final-pdm/bronze/votacao_secao_2016_GO"

# Ler o arquivo diretamente usando pandas e gcsfs
tse = pd.read_csv(gcs_path, encoding='Latin-1', sep=';', storage_options={"token": "google_default"})
tse.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  07/12/2023   14:25:26         2016                2  ELEIÇÃO ORDINÁRIA
# 1  07/12/2023   14:25:26         2016                2  ELEIÇÃO ORDINÁRIA
# 2  07/12/2023   14:25:26         2016                2  ELEIÇÃO ORDINÁRIA
# 3  07/12/2023   14:25:26         2016                2  ELEIÇÃO ORDINÁRIA
# 4  07/12/2023   14:25:26         2016                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         220  ELEIÇÕES MUNICIPAIS 2016  02/10/2016              M
# 1         1         220  ELEIÇÕES MUNICIPAIS 2016  02/10/2016              M
# 2         1         220  ELEIÇÕES MUNICIPAIS 2016  02/10/2016              M
# 3         1         220  ELEIÇÕES MUNICIPAIS 2016  02/10/2016              M
# 4         1         220  ELEIÇÕES MUNICIPAIS 2016  02/10/2016              M
#
#    ... NR_SECAO  CD_CARGO  DS_CARGO  NR_VOTAVEL                    NM_VOTAVEL  \
# 0  ...      146        13  VEREADOR       19234          MARIO MIGUEL GHANNAM
# 1  ...       42        13  VEREADOR       19234          MARIO MIGUEL GHANNAM
# 2  ...       83        13  VEREADOR       44448     MAURENIR COSTA DOS SANTOS
# 3  ...      152        13  VEREADOR       40122  MIRACI LUIZA GONCALVES ALVES
# 4  ...      146        13  VEREADOR       40001          ELIAS VAZ DE ANDRADE
#
#    QT_VOTOS  NR_LOCAL_VOTACAO  SQ_CANDIDATO  \
# 0         1              1244   90000016546
# 1         3              1627   90000016546
# 2         1              1163   90000008185
# 3         1              1163   90000008394
# 4         3              1244   90000014745
#
#                                     NM_LOCAL_VOTACAO  \
# 0              COLÉGIO ESTADUAL MAJOR OSCAR ALVEOLOS
# 1  ESC TEC DE COMERCIO DE CAMPINAS E COLEGIO PRIN...
# 2         ESCOLA ESTADUAL PROFESSOR GERALDO DA SILVA
# 3                    ESCOLA MUNICIPAL SANTA EFIGENIA
# 4              COLÉGIO ESTADUAL MAJOR OSCAR ALVEOLOS
#
#                     DS_LOCAL_VOTACAO_ENDERECO
# 0  RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# 1                  RUA 203 N 96 SETOR COIMBRA
# 2                   RUA VISCONDE DE MAUÁ, S/N
# 3         RUA EUDOXIO GONZAGA, Q. 43, L. 1/28
# 4  RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
#
# [5 rows x 26 columns]

# %%
# features importantes
print(tse.columns)
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'NR_ZONA', 'NR_SECAO', 'CD_CARGO', 'DS_CARGO',
#        'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_LOCAL_VOTACAO',
#        'SQ_CANDIDATO', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO'],
#       dtype='object')

# %%
# alguns dados foram incluidos a partir de 2016
tse['DS_LOCAL_VOTACAO_ENDERECO']
# Out:
# 0           RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# 1                           RUA 203 N 96 SETOR COIMBRA
# 2                            RUA VISCONDE DE MAUÁ, S/N
# 3                  RUA EUDOXIO GONZAGA, Q. 43, L. 1/28
# 4           RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
#                               ...
# 1207674                       RUA MONTE CASTELO NR 108
# 1207675            RUA LACY ESQ. C/ RUA ANACÁ QD 214-A
# 1207676                                 RUA DA LUZ SN
# 1207677                      RUA PAOLA NEY  QD. 59 S/N
# 1207678    RUA 12 DE OUTUBRO ESQ.C/COMENDADOR LEAO S/N
# Name: DS_LOCAL_VOTACAO_ENDERECO, Length: 1207679, dtype: object

# %%
tse = tse[['ANO_ELEICAO','NM_MUNICIPIO','NR_ZONA', 'NR_SECAO', 'CD_TIPO_ELEICAO','NR_TURNO', 'DS_CARGO', 'NM_VOTAVEL', 'NR_VOTAVEL', 'QT_VOTOS', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO']]

# %%
from unidecode import unidecode

# transformações nos dados
# 
# Função para transformar texto: remover acentos e deixar em maiúsculas
def transformar_string(valor):
    if isinstance(valor, str):  # Verifica se é uma string
        return unidecode(valor).upper()
    return valor  # Retorna o valor original se não for string

# Aplica a transformação em todas as colunas de tipo string
for col in tse.select_dtypes(include=["object"]).columns:
    tse[col] = tse[col].apply(transformar_string)

tse
# Out:
#          ANO_ELEICAO          NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 0               2016               GOIANIA      133       146
# 1               2016               GOIANIA        2        42
# 2               2016  APARECIDA DE GOIANIA      145        83
# 3               2016          CALDAS NOVAS        7       152
# 4               2016               GOIANIA      133       146
# ...              ...                   ...      ...       ...
# 1207674         2016               GOIANIA      146       169
# 1207675         2016               GOIANIA      127       229
# 1207676         2016                URUACU       50       111
# 1207677         2016               GOIANIA      136        16
# 1207678         2016             RIO VERDE       30       203
#
#          CD_TIPO_ELEICAO  NR_TURNO  DS_CARGO                    NM_VOTAVEL  \
# 0                      2         1  VEREADOR          MARIO MIGUEL GHANNAM
# 1                      2         1  VEREADOR          MARIO MIGUEL GHANNAM
# 2                      2         1  VEREADOR     MAURENIR COSTA DOS SANTOS
# 3                      2         1  VEREADOR  MIRACI LUIZA GONCALVES ALVES
# 4                      2         1  VEREADOR          ELIAS VAZ DE ANDRADE
# ...                  ...       ...       ...                           ...
# 1207674                2         1  VEREADOR     UILLIAN COSTA DA TRINDADE
# 1207675                2         1  VEREADOR     UILLIAN COSTA DA TRINDADE
# 1207676                2         1  VEREADOR       VALMI MATEUS DA FONSECA
# 1207677                2         1  VEREADOR        ANTONIO UCHOA SOBRINHO
# 1207678                2         1  PREFEITO         HEULER ABREU CRUVINEL
#
#          NR_VOTAVEL  QT_VOTOS  \
# 0             19234         1
# 1             19234         3
# 2             44448         1
# 3             40122         1
# 4             40001         3
# ...             ...       ...
# 1207674       23500         1
# 1207675       23500         2
# 1207676       13015         4
# 1207677       33433         1
# 1207678          55        90
#
#                                           NM_LOCAL_VOTACAO  \
# 0                    COLEGIO ESTADUAL MAJOR OSCAR ALVEOLOS
# 1        ESC TEC DE COMERCIO DE CAMPINAS E COLEGIO PRIN...
# 2               ESCOLA ESTADUAL PROFESSOR GERALDO DA SILVA
# 3                          ESCOLA MUNICIPAL SANTA EFIGENIA
# 4                    COLEGIO ESTADUAL MAJOR OSCAR ALVEOLOS
# ...                                                    ...
# 1207674                  COLEGIO INTERATIVA (ANTIGO EXITO)
# 1207675  COLEGIO ESTADUAL DE 1O E 2O GRAU ANTONIO OLIVE...
# 1207676                ESCOLA ESTADUAL LUIZ CARLOS DA MOTA
# 1207677                   COLEGIO ESTADUAL JARDIM VILA BOA
# 1207678                                   COLEGIO OBJETIVO
#
#                            DS_LOCAL_VOTACAO_ENDERECO
# 0         RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# 1                         RUA 203 N 96 SETOR COIMBRA
# 2                          RUA VISCONDE DE MAUA, S/N
# 3                RUA EUDOXIO GONZAGA, Q. 43, L. 1/28
# 4         RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# ...                                              ...
# 1207674                     RUA MONTE CASTELO NR 108
# 1207675          RUA LACY ESQ. C/ RUA ANACA QD 214-A
# 1207676                               RUA DA LUZ SN
# 1207677                    RUA PAOLA NEY  QD. 59 S/N
# 1207678  RUA 12 DE OUTUBRO ESQ.C/COMENDADOR LEAO S/N
#
# [1207679 rows x 12 columns]

# %%
print(tse.isnull().sum())
# Out:
# ANO_ELEICAO                  0
# NM_MUNICIPIO                 0
# NR_ZONA                      0
# NR_SECAO                     0
# CD_TIPO_ELEICAO              0
# NR_TURNO                     0
# DS_CARGO                     0
# NM_VOTAVEL                   0
# NR_VOTAVEL                   0
# QT_VOTOS                     0
# NM_LOCAL_VOTACAO             0
# DS_LOCAL_VOTACAO_ENDERECO    0
# dtype: int64

# %%
# filtros

tse['NM_MUNICIPIO'].unique()
# Out:
# array(['GOIANIA', 'APARECIDA DE GOIANIA', 'CALDAS NOVAS', 'ANAPOLIS',
#        'ITAGUARU', 'TRINDADE', 'PIRENOPOLIS', 'GOIATUBA',
#        'CORUMBA DE GOIAS', 'ANICUNS', 'ARAGUAPAZ',
#        'SAO LUIS DE MONTES BELOS', 'AGUAS LINDAS DE GOIAS', 'SILVANIA',
#        'PLANALTINA', 'INHUMAS', 'LUZIANIA', 'PALMINOPOLIS',
#        'CIDADE OCIDENTAL', 'MONTE ALEGRE DE GOIAS', 'VILA BOA', 'JAUPACI',
#        'RIO VERDE', 'SENADOR CANEDO', 'CRIXAS', 'ARAGARCAS', 'MOSSAMEDES',
#        'ALOANDIA', 'ITARUMA', 'VALPARAISO DE GOIAS', 'GUARANI DE GOIAS',
#        'SAO SIMAO', 'JARAGUA', 'FLORES DE GOIAS', 'MORRINHOS',
#        'VIANOPOLIS', 'PARAUNA', 'NOVA GLORIA', 'TURVELANDIA', 'GOIANIRA',
#        'NOVO GAMA', 'MONTIVIDIU', 'QUIRINOPOLIS', 'ITUMBIARA',
#        'PIRACANJUBA', 'NOVA AMERICA', 'FORMOSA', 'GUARAITA', 'URUACU',
#        'BURITI ALEGRE', 'APARECIDA DO RIO DOCE', 'CRISTALINA',
#        'CAVALCANTE', 'JATAI', 'ABADIANIA', 'GOIANESIA', 'PONTALINA',
#        'CATURAI', 'IPORA', 'RIALMA', 'COCALZINHO DE GOIAS', 'INDIARA',
#        'JOVIANIA', 'FORMOSO', 'FAINA', 'SANTO ANTONIO DO DESCOBERTO',
#        'GOIANDIRA', 'JUSSARA', 'SANTA BARBARA DE GOIAS',
#        'SAO MIGUEL DO ARAGUAIA', 'SERRANOPOLIS', 'ALEXANIA',
#        'BOM JARDIM DE GOIAS', 'MINACU', 'CAMPINORTE',
#        'PALMEIRAS DE GOIAS', 'NIQUELANDIA', 'EDEIA', 'PORANGATU',
#        'AGUA LIMPA', 'BARRO ALTO', 'POSSE', 'GUARINOS', 'PIRES DO RIO',
#        'CASTELANDIA', 'HEITORAI', 'ACREUNA', 'CATALAO', 'PORTELANDIA',
#        'MATRINCHA', 'GUAPO', 'BOM JESUS DE GOIAS', 'ARAGOIANIA',
#        'SANTA RITA DO NOVO DESTINO', 'CAMPO ALEGRE DE GOIAS', 'PALMELO',
#        'CAMPESTRE DE GOIAS', 'SANTA HELENA DE GOIAS', 'ARENOPOLIS',
#        'MUTUNOPOLIS', 'PADRE BERNARDO', 'AGUA FRIA DE GOIAS', 'RUBIATABA',
#        'PARANAIGUARA', 'MOZARLANDIA', 'NAZARIO', 'ITAJA', 'SANCLERLANDIA',
#        'FIRMINOPOLIS', 'MINEIROS', 'AURILANDIA', 'MIMOSO DE GOIAS',
#        'TEREZOPOLIS DE GOIAS', 'MORRO AGUDO DE GOIAS', 'ISRAELANDIA',
#        'MAURILANDIA', 'CAMPOS BELOS', 'URUANA', 'NEROPOLIS', 'CACU',
#        'URUTAI', 'MONTIVIDIU DO NORTE', 'MAMBAI', 'BELA VISTA DE GOIAS',
#        'CACHOEIRA DOURADA', 'ITAUCU', 'IACIARA', 'IPAMERI', 'ADELANDIA',
#        'GOIAS', 'CAIAPONIA', 'ABADIA DE GOIAS', 'ITAPACI',
#        'SANTA FE DE GOIAS', 'ITAGUARI', 'ITABERAI', 'TAQUARAL DE GOIAS',
#        'TURVANIA', 'CERES', 'DAMOLANDIA', 'ITAPURANGA', 'PANAMA',
#        'NOVA VENEZA', 'SANTA CRUZ DE GOIAS', 'NOVO BRASIL',
#        'SANTA RITA DO ARAGUAIA', 'IVOLANDIA', 'BONFINOPOLIS',
#        'AMERICANO DO BRASIL', 'UIRAPURU', 'VARJAO', 'EDEALINA',
#        'HIDROLANDIA', 'SAO JOAO D ALIANCA', 'OURO VERDE DE GOIAS',
#        'ESTRELA DO NORTE', 'CAMPINACU', 'PILAR DE GOIAS',
#        'CARMO DO RIO VERDE', 'AMARALINA', 'RIO QUENTE', 'MAIRIPOTABA',
#        'CRISTIANOPOLIS', 'ALTO HORIZONTE', 'CALDAZINHA', 'VILA PROPICIO',
#        'IPIRANGA DE GOIAS', 'OUVIDOR', 'MONTES CLAROS DE GOIAS',
#        'CABECEIRAS', 'CORREGO DO OURO', 'MUNDO NOVO',
#        'SAO JOAO DA PARAUNA', 'MOIPORA', 'ARUANA', 'NOVA ROMA',
#        'RIANAPOLIS', 'NOVO PLANALTO', 'PORTEIRAO', 'CACHOEIRA ALTA',
#        'MARA ROSA', 'BALIZA', 'INACIOLANDIA', 'GOIANAPOLIS', 'CORUMBAIBA',
#        'ANHANGUERA', 'ITAPIRAPUA', 'FAZENDA NOVA', 'JANDAIA',
#        'SAO DOMINGOS', 'LEOPOLDO DE BULHOES', 'DOVERLANDIA',
#        'CAMPOS VERDES', 'SAO LUIZ DO NORTE', 'CEZARINA',
#        'PROFESSOR JAMIL', 'SAO PATRICIO', 'ORIZONA',
#        'CAMPO LIMPO DE GOIAS', 'TROMBAS', 'ARACU', 'DIORAMA',
#        'CHAPADAO DO CEU', 'VICENTINOPOLIS', 'SANTA TEREZINHA DE GOIAS',
#        'AMORINOPOLIS', 'SANTA ISABEL', 'ALTO PARAISO DE GOIAS',
#        'SIMOLANDIA', 'COLINAS DO SUL', 'SANTO ANTONIO DE GOIAS',
#        'SANTA ROSA DE GOIAS', 'BONOPOLIS', 'APORE', 'AVELINOPOLIS',
#        'BRITANIA', 'HIDROLINA', 'SANTO ANTONIO DA BARRA', 'JESUPOLIS',
#        'GOUVELANDIA', 'SAO MIGUEL DO PASSA QUATRO', 'PALESTINA DE GOIAS',
#        'TRES RANCHOS', 'NOVA CRIXAS', 'PETROLINA DE GOIAS',
#        'ALVORADA DO NORTE', 'PIRANHAS', 'NOVA AURORA', 'CUMARI',
#        'SITIO D ABADIA', 'SANTA TEREZA DE GOIAS', 'PEROLANDIA',
#        'CROMINIA', 'SAO FRANCISCO DE GOIAS', 'DAMIANOPOLIS',
#        'NOVA IGUACU DE GOIAS', 'BRAZABRANTES', 'DAVINOPOLIS',
#        'DIVINOPOLIS DE GOIAS', 'CACHOEIRA DE GOIAS', 'GAMELEIRA DE GOIAS',
#        'TERESINA DE GOIAS', 'BURITINOPOLIS', 'MARZAGAO', 'LAGOA SANTA',
#        'BURITI DE GOIAS'], dtype=object)

# %%
tse = tse[tse["NM_MUNICIPIO"] == 'GOIANIA']
tse = tse[tse["DS_CARGO"] == 'VEREADOR']

# %%
tse.head()
# Out:
#    ANO_ELEICAO NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  NR_TURNO  \
# 0         2016      GOIANIA      133       146                2         1
# 1         2016      GOIANIA        2        42                2         1
# 4         2016      GOIANIA      133       146                2         1
# 5         2016      GOIANIA      146       259                2         1
# 8         2016      GOIANIA      133       244                2         1
#
#    DS_CARGO            NM_VOTAVEL  NR_VOTAVEL  QT_VOTOS  \
# 0  VEREADOR  MARIO MIGUEL GHANNAM       19234         1
# 1  VEREADOR  MARIO MIGUEL GHANNAM       19234         3
# 4  VEREADOR  ELIAS VAZ DE ANDRADE       40001         3
# 5  VEREADOR  ELIAS VAZ DE ANDRADE       40001         1
# 8  VEREADOR  ELIAS VAZ DE ANDRADE       40001         7
#
#                                     NM_LOCAL_VOTACAO  \
# 0              COLEGIO ESTADUAL MAJOR OSCAR ALVEOLOS
# 1  ESC TEC DE COMERCIO DE CAMPINAS E COLEGIO PRIN...
# 4              COLEGIO ESTADUAL MAJOR OSCAR ALVEOLOS
# 5                                    CAMPUS II - UFG
# 8           ESCOLA PIAGET - PISO SUPERIOR (RUA 1026)
#
#                            DS_LOCAL_VOTACAO_ENDERECO
# 0         RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# 1                         RUA 203 N 96 SETOR COIMBRA
# 4         RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# 5              CAMPUS II - UFG - CONJUNTO ITATIAIA I
# 8  RUA 1.026, QUADRA 68, LOTES 08/25, SETOR PEDRO...

# %%
# Agregação com tabela zonas

# Ler o arquivo diretamente usando pandas e gcsfs
zonas_info = pd.read_csv('gs://trabalho-final-pdm/bronze/zonas_goiania', storage_options={"token": "google_default"})

zonas_info = zonas_info[['ZONA', 'LOCAL DE VOTACAO', 'ENDEREÇO', 'BAIRRO']]

# Aplica a transformação em todas as colunas de tipo string
for col in zonas_info.select_dtypes(include=["object"]).columns:
    zonas_info[col] = zonas_info[col].apply(transformar_string)
zonas_info
# Out:
#      ZONA                                   LOCAL DE VOTACAO  \
# 0       1        COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA
# 1     147                                    COLEGIO DESAFIO
# 2     136                   COLEGIO ESTADUAL JARDIM VILA BOA
# 3     127                        ESCOLA SESI JARDIM PLANALTO
# 4     127   COLEGIO ESTADUAL POLIVALENTE PROFO GOIANY PRATES
# ..    ...                                                ...
# 351   134  ESCOLA MUNICIPAL PROFESSOR SALMON GOMES FIGUEI...
# 352     2                       UNIALFA - UNIDADE PERIMETRAL
# 353   127                                    COLEGIO DEGRAUS
# 354   147                      ESCOLA MUNICIPAL ALTO DO VALE
# 355   133  ESCOLA MUNICIPAL PROFESSORA AMELIA FERNANDES M...
#
#                                          ENDEREÇO               BAIRRO
# 0                           AV K, 108 - UNIDADE I      SETOR AEROPORTO
# 1                          AV MANGALO QD 55 LT 06  SETOR MORADA DO SOL
# 2                            RUA PAOLA NEY QD. 59      JARDIM VILA BOA
# 3                          PRACA ITAPUA QD 30 150      JARDIM PLANALTO
# 4                             RUA C-68 QD 115 336      VILAS DOS ALPES
# ..                                            ...                  ...
# 351                RUA SAO DOMINGOS QD. 91 LT. 04   JARDIM PETROPOLIS
# 352                      AV PERIMETRAL NORTE 4129     SETOR GOIANIA II
# 353                                 RUA U-79A, 25          VILA UNIAO
# 354  RUA SAMIR HELOU COM RUA VF 15, QD. 6, LT. 19  SETOR ALTO DO VALE
# 355                                RUA OCANAN, 50     PARQUE ACALANTO
#
# [356 rows x 4 columns]

# %%
tse['NR_ZONA'] = tse['NR_ZONA'].astype(int)
zonas_info['ZONA'] = zonas_info['ZONA'].astype(int)

# %%
# Agrupar zonas_info pela coluna ZONA, garantindo que nenhuma informação seja perdida
zonas_info_agrupado = zonas_info.groupby("ZONA").agg({
    "LOCAL DE VOTACAO": lambda x: list(x),
    "ENDEREÇO": lambda x: list(x),
    "BAIRRO": lambda x: list(x)
}).reset_index()

# %%
# Realizar a junção das tabelas usando colunas com nomes diferentes
tse_unificado = pd.merge(
    tse, 
    zonas_info_agrupado, 
    left_on="NR_ZONA",  # Coluna na tabela tse
    right_on="ZONA", # Coluna na tabela zonas_info
    how="left"       # Manter todas as linhas de tse
)

# Remover a duplicata da coluna Zona, se necessário
tse_unificado.drop(columns=["ZONA"], inplace=True)

# Visualizar o resultado
tse_unificado
# Out:
#         ANO_ELEICAO NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  \
# 0              2016      GOIANIA      133       146                2
# 1              2016      GOIANIA        2        42                2
# 2              2016      GOIANIA      133       146                2
# 3              2016      GOIANIA      146       259                2
# 4              2016      GOIANIA      133       244                2
# ...             ...          ...      ...       ...              ...
# 305961         2016      GOIANIA      147       311                2
# 305962         2016      GOIANIA      146       169                2
# 305963         2016      GOIANIA      146       169                2
# 305964         2016      GOIANIA      127       229                2
# 305965         2016      GOIANIA      136        16                2
#
#         NR_TURNO  DS_CARGO                 NM_VOTAVEL  NR_VOTAVEL  QT_VOTOS  \
# 0              1  VEREADOR       MARIO MIGUEL GHANNAM       19234         1
# 1              1  VEREADOR       MARIO MIGUEL GHANNAM       19234         3
# 2              1  VEREADOR       ELIAS VAZ DE ANDRADE       40001         3
# 3              1  VEREADOR       ELIAS VAZ DE ANDRADE       40001         1
# 4              1  VEREADOR       ELIAS VAZ DE ANDRADE       40001         7
# ...          ...       ...                        ...         ...       ...
# 305961         1  VEREADOR  UILLIAN COSTA DA TRINDADE       23500         1
# 305962         1  VEREADOR        GILMAR BRAZ PEREIRA       18700         1
# 305963         1  VEREADOR  UILLIAN COSTA DA TRINDADE       23500         1
# 305964         1  VEREADOR  UILLIAN COSTA DA TRINDADE       23500         2
# 305965         1  VEREADOR     ANTONIO UCHOA SOBRINHO       33433         1
#
#                                          NM_LOCAL_VOTACAO  \
# 0                   COLEGIO ESTADUAL MAJOR OSCAR ALVEOLOS
# 1       ESC TEC DE COMERCIO DE CAMPINAS E COLEGIO PRIN...
# 2                   COLEGIO ESTADUAL MAJOR OSCAR ALVEOLOS
# 3                                         CAMPUS II - UFG
# 4                ESCOLA PIAGET - PISO SUPERIOR (RUA 1026)
# ...                                                   ...
# 305961                   ESCOLA MUNICIPAL ELI BRASILIENSE
# 305962                  COLEGIO INTERATIVA (ANTIGO EXITO)
# 305963                  COLEGIO INTERATIVA (ANTIGO EXITO)
# 305964  COLEGIO ESTADUAL DE 1O E 2O GRAU ANTONIO OLIVE...
# 305965                   COLEGIO ESTADUAL JARDIM VILA BOA
#
#                                 DS_LOCAL_VOTACAO_ENDERECO  \
# 0              RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# 1                              RUA 203 N 96 SETOR COIMBRA
# 2              RUA 2011, UNIDADE 201, S/N, PARQUE ATHENEU
# 3                   CAMPUS II - UFG - CONJUNTO ITATIAIA I
# 4       RUA 1.026, QUADRA 68, LOTES 08/25, SETOR PEDRO...
# ...                                                   ...
# 305961    RUA DONA CAROLINA ESQ. C/ RUA GV-16 QD 40 N 151
# 305962                           RUA MONTE CASTELO NR 108
# 305963                           RUA MONTE CASTELO NR 108
# 305964                RUA LACY ESQ. C/ RUA ANACA QD 214-A
# 305965                          RUA PAOLA NEY  QD. 59 S/N
#
#                                          LOCAL DE VOTACAO  \
# 0       [COLEGIO DINAMICO, COLEGIO MARISTA, CENTRO DE ...
# 1       [CENTRO DE ENSINO EM PERIODO INTEGRAL AECIO OL...
# 2       [COLEGIO DINAMICO, COLEGIO MARISTA, CENTRO DE ...
# 3       [CEPMGO WALDEMAR MUNDIM, CEPMGO JARDIM GUANABA...
# 4       [COLEGIO DINAMICO, COLEGIO MARISTA, CENTRO DE ...
# ...                                                   ...
# 305961  [COLEGIO DESAFIO, COLEGIO ESTADUAL PROFESSOR J...
# 305962  [CEPMGO WALDEMAR MUNDIM, CEPMGO JARDIM GUANABA...
# 305963  [CEPMGO WALDEMAR MUNDIM, CEPMGO JARDIM GUANABA...
# 305964  [ESCOLA SESI JARDIM PLANALTO, COLEGIO ESTADUAL...
# 305965  [COLEGIO ESTADUAL JARDIM VILA BOA, COLEGIO MUN...
#
#                                                  ENDEREÇO  \
# 0       [RUA T-37 2693, AVENIDA 85, 1440, RUA 1016, 42...
# 1       [RUA CARIJOS COM RUA DO PRATA, AV SOL NASCENTE...
# 2       [RUA T-37 2693, AVENIDA 85, 1440, RUA 1016, 42...
# 3       [RUA R-40 QD40 LT07, ALAMEDA MINAS GERAIS QD.7...
# 4       [RUA T-37 2693, AVENIDA 85, 1440, RUA 1016, 42...
# ...                                                   ...
# 305961  [AV MANGALO QD 55 LT 06, AV. FERNAO DIAS PAES ...
# 305962  [RUA R-40 QD40 LT07, ALAMEDA MINAS GERAIS QD.7...
# 305963  [RUA R-40 QD40 LT07, ALAMEDA MINAS GERAIS QD.7...
# 305964  [PRACA ITAPUA QD 30 150, RUA C-68 QD 115 336, ...
# 305965  [RUA PAOLA NEY QD. 59, RUA B-16 101, RUA 3 B Q...
#
#                                                    BAIRRO
# 0       [SETOR BUENO, SETOR MARISTA, SETOR PEDRO LUDOV...
# 1       [SETOR URIAS MAGALHAES, JARDIM NOVA ESPERANCA,...
# 2       [SETOR BUENO, SETOR MARISTA, SETOR PEDRO LUDOV...
# 3       [VILA ITATIAIA, JARDIM GUANABARA, LESTE VILA N...
# 4       [SETOR BUENO, SETOR MARISTA, SETOR PEDRO LUDOV...
# ...                                                   ...
# 305961  [SETOR MORADA DO SOL, CAPUAVA, VILA MULTIRAO, ...
# 305962  [VILA ITATIAIA, JARDIM GUANABARA, LESTE VILA N...
# 305963  [VILA ITATIAIA, JARDIM GUANABARA, LESTE VILA N...
# 305964  [JARDIM PLANALTO, VILAS DOS ALPES, JARDIM AMER...
# 305965  [JARDIM VILA BOA, VILA NOVO HORIZONTE, SETOR G...
#
# [305966 rows x 15 columns]

# %%
# Salvar DataFrame diretamente no GCS
gcs_path = "gs://trabalho-final-pdm/silver/tse_bairros_2016.csv"

# Escrever para o Cloud Storage usando storage_options
tse_unificado.to_csv(gcs_path, index=False, storage_options={"token": "google_default"})
