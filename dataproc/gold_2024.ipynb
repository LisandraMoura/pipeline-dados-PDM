# %%
import pandas as pd 

agrega = pd.read_csv('gs://trabalho-final-pdm/silver/agregados_2024.csv', storage_options={"token": "google_default"})
# Preparação: adicionar uma coluna de renda média (V005 + V009)
agrega['RENDA'] = agrega['V005'] + agrega['V009']

# %%
# 1. NR_VOTAVEL com maior número de votos por Nome_do_subdistrito
# 2. NM_VOTAVEL com maior número de votos por Nome_do_subdistrito
nr_votavel_subdistrito = agrega.groupby(['Nome_do_subdistrito', 'NR_VOTAVEL', 'NM_VOTAVEL'])['QT_VOTOS'].sum().reset_index()
nr_votavel_max = nr_votavel_subdistrito.loc[nr_votavel_subdistrito.groupby('Nome_do_subdistrito')['QT_VOTOS'].idxmax()]

# Partidos políticos mais bem votados por bairro
# Candidato com maior numero de votos por bairro
nr_votavel_max.sort_values('QT_VOTOS')
# Out:
#                                      Nome_do_subdistrito  NR_VOTAVEL  \
# 62747                                          VILA RICA          44
# 62603                                  U.T.P. ZONA RURAL          15
# 62388                                  U.T.P. VILA RIZZO          22
# 1005                    U.T.P. ALTO DA GLORIA E REDENCAO          44
# 18991                              U.T.P. JARDIM AMERICA          22
# 39694                            U.T.P. PARQUE BOM JESUS          44
# 45616                              U.T.P. SANTA GENOVEVA          44
# 10652        U.T.P. CELINA PARK/RECREIO DOS FUNCIONARIOS          22
# 45079                         U.T.P. RIVIERA/AGUA BRANCA          44
# 13132                        U.T.P. CHACARAS SAO JOAQUIM          44
# 13972                               U.T.P. CIDADE JARDIM          22
# 2752                                U.T.P. BALIZA-ITAIPU          44
# 18654                                         U.T.P. JAO          44
# 24159                           U.T.P. JARDIM PETROPOLIS          22
# 57222  U.T.P. VILA JARDIM SAO JUDAS TADEU/JARDIM POMPEIA          44
# 30970                             U.T.P. MARECHAL RONDON          22
# 14490                                     U.T.P. COIMBRA          44
# 49149                               U.T.P. SANTO HILARIO          44
# 33027                              U.T.P. NEGRAO DE LIMA          44
# 41966                           U.T.P. PARQUE SANTA RITA          44
# 55360                             U.T.P. URIAS MAGALHAES          22
# 16220                                  U.T.P. GOIANIA II          44
# 6190                                      U.T.P. CAPUAVA          44
# 40511      U.T.P. PARQUE DAS LARANJEIRAS E JARDIM DA LUZ          44
# 31571                                     U.T.P. MARISTA          44
# 53658                                         U.T.P. SUL          44
# 61022                                U.T.P. VILA PEDROSO          44
# 53052                                    U.T.P. SUDOESTE          22
# 44                                      U.T.P. AEROPORTO          44
# 31994                          U.T.P. MUTIRAO E CURITIBA          44
# 4563       U.T.P. CAMPUS UNIVERSITARIO/CONJUNTO ITATIAIA          44
# 46004                               U.T.P. SANTO ANTONIO          44
# 41037                     U.T.P. PARQUE OESTE INDUSTRIAL          22
# 26127                                   U.T.P. JOAO BRAZ          15
# 50017                                U.T.P. SAO DOMINGOS          15
# 19963                               U.T.P. JARDIM EUROPA          22
# 61392  U.T.P. VILA REGINA/PARQUE INDUSTRIAL PAULISTA/...          22
# 20518                                U.T.P. JARDIM GOIAS          44
# 24555      U.T.P. JARDIM PRIMAVERA (AREA URBANA ISOLADA)          44
# 19452  U.T.P. JARDIM BALNEARIO MEIA PONTE/MANSOES GOI...          22
# 3655                                     U.T.P. CAMPINAS          44
# 34154                           U.T.P. NORTE FERROVIARIO          11
# 24555          LUCAS DE CARVALHO ANTONIETTI      7291
# 19452  FREDERICO GUSTAVO RODRIGUES DA CUNHA      7430
# 3655         SANDRO DA MABEL ANTONIO SCODRO      7508
# 34154        CRISTIOMARIO DE SOUSA MEDEIROS      7789
# 35129  FREDERICO GUSTAVO RODRIGUES DA CUNHA      8528
# 56073        SANDRO DA MABEL ANTONIO SCODRO      8586
# 5198         SANDRO DA MABEL ANTONIO SCODRO      9540
# 30393        SANDRO DA MABEL ANTONIO SCODRO      9819
# 15638        SANDRO DA MABEL ANTONIO SCODRO      9844
# 36883        SANDRO DA MABEL ANTONIO SCODRO     11342
# 1277                  MARCIO AURELIO CORREA     11559
# 22717        SANDRO DA MABEL ANTONIO SCODRO     13076
# 3092         SANDRO DA MABEL ANTONIO SCODRO     13547
# 11074        SANDRO DA MABEL ANTONIO SCODRO     14284
# 23215        SANDRO DA MABEL ANTONIO SCODRO     14520
# 6927         SANDRO DA MABEL ANTONIO SCODRO     19369
# 43270        SANDRO DA MABEL ANTONIO SCODRO     21661
# 38078        SANDRO DA MABEL ANTONIO SCODRO     24336
# 57861        SANDRO DA MABEL ANTONIO SCODRO     43661

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-bairro-2024"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(nr_votavel_max, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-bairro-2024 exportada com sucesso!

# %%
# 3. NM_VOTAVEL com maior número de votos por renda
# 4. NR_VOTAVEL com maior número de votos por renda
# Ordenar por renda para pegar as rendas mais altas e baixas
nm_votavel_renda = agrega.groupby(['RENDA','NR_VOTAVEL','NM_VOTAVEL'])['QT_VOTOS'].sum().reset_index()
renda_sorted = nm_votavel_renda.sort_values(by='RENDA')

# Candidato e partido com maior quantidade de votos por renda (renda baixa e alta)
renda_sorted
# Out:
#           RENDA  NR_VOTAVEL                            NM_VOTAVEL  QT_VOTOS
# 0       1070.39          13              ADRIANA SAUTHIER ACCORSI        69
# 1       1070.39          13             PARTIDO DOS TRABALHADORES         2
# 2       1070.39          22  FREDERICO GUSTAVO RODRIGUES DA CUNHA        64
# 38      1070.39       40100              LUCILENE DOS SANTOS ROSA         1
# 37      1070.39       36789               JAIME MONTEIRO DA SILVA         4
# ...         ...         ...                                   ...       ...
# 62785  17065.38       77900      FRANCIVALDO RIBEIRO DA CONCEICAO         2
# 62784  17065.38       77890                    PETRONIO DIAS LIMA        39
# 62783  17065.38       77888          LEILA MARTINS DA SILVA MATOS        88
# 62732  17065.38       77369               LUCAS DA SILVA CAMARGOS         2
# 62780  17065.38       77888       FLAVIA FERREIRA MUNDIM DE PAULO         4
#
# [62791 rows x 4 columns]

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-renda-2024"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(nr_votavel_max, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-renda-2024 exportada com sucesso!
