# %%
import pandas as pd 

agrega = pd.read_csv('gs://trabalho-final-pdm/silver/agregados_2024.csv', storage_options={"token": "google_default"})
# Preparação: adicionar uma coluna de renda média (V005 + V009)
agrega['RENDA'] = agrega['V005'] + agrega['V009']

# %%
# 1. NR_VOTAVEL com maior número de votos por Nome_do_subdistrito
# 2. NM_VOTAVEL com maior número de votos por Nome_do_subdistrito
nr_votavel_subdistrito = agrega.groupby(['Nome_do_subdistrito', 'NR_VOTAVEL', 'NM_VOTAVEL', 'Proporcao_negros_pardos_indigenas', 'Proporcao_feminino', 'Proporcao_18_39'])['QT_VOTOS'].sum().reset_index()
nr_votavel_max = nr_votavel_subdistrito.loc[nr_votavel_subdistrito.groupby('Nome_do_subdistrito')['QT_VOTOS'].idxmax()]

# Partidos políticos mais bem votados por bairro
# Candidato com maior numero de votos por bairro
nr_votavel_max.sort_values('QT_VOTOS')
# Out:
#                                      Nome_do_subdistrito  NR_VOTAVEL  \
# 7826                               U.T.P. JARDIM AMERICA       45456
# 22601                                  U.T.P. VILA RIZZO          95
# 541                     U.T.P. ALTO DA GLORIA E REDENCAO       25025
# 22828                                          VILA RICA       36633
# 13579                           U.T.P. NORTE FERROVIARIO          95
# 15472                            U.T.P. PARQUE BOM JESUS       10700
# 5712                                U.T.P. CIDADE JARDIM          95
# 18028                               U.T.P. SANTO ANTONIO          95
# 17962                              U.T.P. SANTA GENOVEVA       55555
# 6089                                      U.T.P. COIMBRA          96
# 4535         U.T.P. CELINA PARK/RECREIO DOS FUNCIONARIOS       11456
# 10461                           U.T.P. JARDIM PETROPOLIS       28000
# 12069                             U.T.P. MARECHAL RONDON       22300
# 17498                         U.T.P. RIVIERA/AGUA BRANCA       22100
# 19111                                    U.T.P. SUDOESTE          96
# 16415                           U.T.P. PARQUE SANTA RITA          96
# 19620                                         U.T.P. SUL       13100
# 18542                               U.T.P. SANTO HILARIO       28147
# 7581                                          U.T.P. JAO       40233
# 12463                                     U.T.P. MARISTA       22222
# 13380                              U.T.P. NEGRAO DE LIMA       28100
# 92                                      U.T.P. AEROPORTO       13100
# 10952                                   U.T.P. JOAO BRAZ          95
# 8350                                U.T.P. JARDIM EUROPA          95
# 22404  U.T.P. VILA REGINA/PARQUE INDUSTRIAL PAULISTA/...       28000
# 20150                             U.T.P. URIAS MAGALHAES       28123
# 12844                          U.T.P. MUTIRAO E CURITIBA       15678
# 2034                                     U.T.P. CAMPINAS          96
# 1479                                U.T.P. BALIZA-ITAIPU       70456
# 8985                                 U.T.P. JARDIM GOIAS       22222
# 2959                U.T.P. CANDIDA DE MORAIS/MARIA DILCE          95
# 5431                         U.T.P. CHACARAS SAO JOAQUIM       11800
# 22164                                U.T.P. VILA PEDROSO       77100
# 19054                                U.T.P. SAO DOMINGOS       70115
# 7059                                   U.T.P. GOIANIA II       15200
# 20618                                   U.T.P. VERA CRUZ       28630
# 15993                     U.T.P. PARQUE OESTE INDUSTRIAL       11456
# 14526                                       U.T.P. OESTE       22222
# 10811            0.494135         0.256598      1019
# 20871            0.544177         0.225904      1059
# 2641             0.503597         0.253397      1061
# 8096             0.541314         0.229873      1163
# 900              0.527446         0.193317      1188
# 17247            0.565060         0.236145      1388
# 21178            0.560498         0.218861      2097
# 15451            0.521088         0.236735      2357
# 9381             0.525701         0.214953      4713

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-bairro-2024"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(nr_votavel_max, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-bairro-2024 exportada com sucesso!

# %%
# 3. NM_VOTAVEL com maior número de votos por renda
# 4. NR_VOTAVEL com maior número de votos por renda
# Ordenar por renda para pegar as rendas mais altas e baixas
nm_votavel_renda = agrega.groupby(['RENDA','NR_VOTAVEL','NM_VOTAVEL', 'Proporcao_negros_pardos_indigenas', 'Proporcao_feminino', 'Proporcao_18_39'])['QT_VOTOS'].sum().reset_index()
renda_sorted = nm_votavel_renda.sort_values(by='RENDA')

# Candidato e partido com maior quantidade de votos por renda (renda baixa e alta)
renda_sorted
# Out:
#           RENDA  NR_VOTAVEL                      NM_VOTAVEL  \
# 0       1070.39          13       PARTIDO DOS TRABALHADORES
# 1       1070.39          33            MOBILIZACAO NACIONAL
# 2       1070.39          36                            AGIR
# 3       1070.39          44                    UNIAO BRASIL
# 28      1070.39       36333  MARCOS ANTONIO MENEZES MARQUES
# ...         ...         ...                             ...
# 22834  17065.38       77746                 SANDRA SILVEIRA
# 22833  17065.38       77700  PAULO HENRIQUE RODRIGUES SILVA
# 22779  17065.38       70038          BRENER FRANCISCO COUTO
# 22767  17065.38       65123              MARIA ISAURA LEMOS
# 22715  17065.38       44789          THAIS APARECIDA SANTOS
#
#        Proporcao_negros_pardos_indigenas  Proporcao_feminino  Proporcao_18_39  \
# 0                               0.626374            0.520879         0.219780
# 1                               0.626374            0.520879         0.219780
# 2                               0.626374            0.520879         0.219780
# 3                               0.626374            0.520879         0.219780
# 28                              0.626374            0.520879         0.219780
# ...                                  ...                 ...              ...
# 22834                           0.158405            0.513390         0.156695
# 22833                           0.158405            0.513390         0.156695
# 22779                           0.158405            0.513390         0.156695
# 22767                           0.158405            0.513390         0.156695
# 22715                           0.158405            0.513390         0.156695
#
#        QT_VOTOS
# 0             2
# 1             1
# 2             2
# 3             1
# 28            1
# ...         ...
# 22834        16
# 22833       213
# 22779        31
# 22767        54
# 22715        26
#
# [22841 rows x 7 columns]

# %%
from google.cloud import bigquery
import pandas as pd

# Configuração
client = bigquery.Client()
table_ref = "pdm-class-2024.gold.infos-por-renda-2024"

# Carregar o DataFrame para o BigQuery
job = client.load_table_from_dataframe(renda_sorted, table_ref)
job.result()

print(f"Tabela {table_ref} exportada com sucesso!")
# Out:
# Tabela pdm-class-2024.gold.infos-por-renda-2024 exportada com sucesso!

# %%
#### INCLUIR NOVAS CONSULTAS GOLDS
