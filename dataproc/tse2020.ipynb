# %%
import pandas as pd

# Caminho do arquivo no GCS
gcs_path = "gs://trabalho-final-pdm/bronze/votacao_secao_2020_GO"

# Ler o arquivo diretamente usando pandas e gcsfs
tse = pd.read_csv(gcs_path, encoding='Latin-1', sep=';', storage_options={"token": "google_default"})
tse.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  16/09/2024   17:49:23         2020                2  Eleição Ordinária
# 1  16/09/2024   17:49:23         2020                2  Eleição Ordinária
# 2  16/09/2024   17:49:23         2020                2  Eleição Ordinária
# 3  16/09/2024   17:49:23         2020                2  Eleição Ordinária
# 4  16/09/2024   17:49:23         2020                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         426  Eleições Municipais 2020  15/11/2020              M
# 1         1         426  Eleições Municipais 2020  15/11/2020              M
# 2         1         426  Eleições Municipais 2020  15/11/2020              M
# 3         1         426  Eleições Municipais 2020  15/11/2020              M
# 4         1         426  Eleições Municipais 2020  15/11/2020              M
#
#    ... NR_SECAO  CD_CARGO  DS_CARGO  NR_VOTAVEL                    NM_VOTAVEL  \
# 0  ...      666        11  Prefeito          15         MARCIO AURELIO CORREA
# 1  ...      305        11  Prefeito          15         MARCIO AURELIO CORREA
# 2  ...      138        11  Prefeito          19  LUCAS DE CARVALHO ANTONIETTI
# 3  ...       20        11  Prefeito          95                   VOTO BRANCO
# 4  ...       53        11  Prefeito          19  LUCAS DE CARVALHO ANTONIETTI
#
#    QT_VOTOS  NR_LOCAL_VOTACAO  SQ_CANDIDATO  \
# 0        35              2208   90001100716
# 1        38              1449   90001100716
# 2       134              1244   90000736702
# 3         1              1066            -1
# 4       186              1082   90000736702
#
#                             NM_LOCAL_VOTACAO  \
# 0                                       SESI
# 1  ESCOLA MUNICIPAL REALINO JOSE DE OLIVEIRA
# 2                    COLÉGIO ESTADUAL PIAGET
# 3         ESCOLA ESTADUAL CEL BENTO DE GODOY
# 4    ESCOLA MUNICIPAL ANTÔNIO DE JESUS LEITE
#
#                    DS_LOCAL_VOTACAO_ENDERECO
# 0                       AV FERNANDO COSTA SN
# 1                       RUA GVE QD 08  LT 20
# 2                      QUADRA 32, LOTE 11/12
# 3  RUA ANTONIO INOCENCIO DE OLIVEIRA, NR 386
# 4            AREA ESPECIAL QUADRA 15 LOTE 01
#
# [5 rows x 26 columns]

# %%
# features importantes
print(tse.columns)
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'NR_ZONA', 'NR_SECAO', 'CD_CARGO', 'DS_CARGO',
#        'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_LOCAL_VOTACAO',
#        'SQ_CANDIDATO', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO'],
#       dtype='object')

# %%
# alguns dados foram incluidos a partir de 2016
tse['DS_LOCAL_VOTACAO_ENDERECO']
# Out:
# 0                               AV FERNANDO COSTA SN
# 1                               RUA GVE QD 08  LT 20
# 2                              QUADRA 32, LOTE 11/12
# 3          RUA ANTONIO INOCENCIO DE OLIVEIRA, NR 386
# 4                    AREA ESPECIAL QUADRA 15 LOTE 01
#                              ...
# 1302464       CONJUNTO HABITACIONAL RIO VERMELHO SN
# 1302465                                 RUA 36 N 391
# 1302466                RUA ILMA TIBURCIO BRAGA , S/N
# 1302467                             RUA MORRINHOS SN
# 1302468             RUA PEDRA DE FOGO, QD. 17 LT. 16
# Name: DS_LOCAL_VOTACAO_ENDERECO, Length: 1302469, dtype: object

# %%
tse = tse[['ANO_ELEICAO','NM_MUNICIPIO','NR_ZONA', 'NR_SECAO', 'CD_TIPO_ELEICAO','NR_TURNO', 'DS_CARGO', 'NM_VOTAVEL', 'NR_VOTAVEL', 'QT_VOTOS', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO']]

# %%
from unidecode import unidecode

# transformações nos dados
# 
# Função para transformar texto: remover acentos e deixar em maiúsculas
def transformar_string(valor):
    if isinstance(valor, str):  # Verifica se é uma string
        return unidecode(valor).upper()
    return valor  # Retorna o valor original se não for string

# Aplica a transformação em todas as colunas de tipo string
for col in tse.select_dtypes(include=["object"]).columns:
    tse[col] = tse[col].apply(transformar_string)

tse
# Out:
#          ANO_ELEICAO           NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 0               2020               ANAPOLIS        3       666
# 1               2020               ANAPOLIS      144       305
# 2               2020  AGUAS LINDAS DE GOIAS       28       138
# 3               2020           CALDAS NOVAS        7        20
# 4               2020  AGUAS LINDAS DE GOIAS       28        53
# ...              ...                    ...      ...       ...
# 1302464         2020                JARAGUA       17        35
# 1302465         2020              GOIANESIA       74        12
# 1302466         2020               ANAPOLIS        3       391
# 1302467         2020               ANAPOLIS      144       215
# 1302468         2020             BARRO ALTO       74       222
#
#          CD_TIPO_ELEICAO  NR_TURNO  DS_CARGO                    NM_VOTAVEL  \
# 0                      2         1  PREFEITO         MARCIO AURELIO CORREA
# 1                      2         1  PREFEITO         MARCIO AURELIO CORREA
# 2                      2         1  PREFEITO  LUCAS DE CARVALHO ANTONIETTI
# 3                      2         1  PREFEITO                   VOTO BRANCO
# 4                      2         1  PREFEITO  LUCAS DE CARVALHO ANTONIETTI
# ...                  ...       ...       ...                           ...
# 1302464                2         1  VEREADOR  LUZINETE DA SILVA ROSA SOUZA
# 1302465                2         1  VEREADOR                   VOTO BRANCO
# 1302466                2         1  VEREADOR     FREDERICO MOREIRA CAIXETA
# 1302467                2         1  VEREADOR          HUMBERTO SOUZA GOMES
# 1302468                2         1  VEREADOR  SANDRO MANUEL SILVA FERREIRA
#
#          NR_VOTAVEL  QT_VOTOS                           NM_LOCAL_VOTACAO  \
# 0                15        35                                       SESI
# 1                15        38  ESCOLA MUNICIPAL REALINO JOSE DE OLIVEIRA
# 2                19       134                    COLEGIO ESTADUAL PIAGET
# 3                95         1         ESCOLA ESTADUAL CEL BENTO DE GODOY
# 4                19       186    ESCOLA MUNICIPAL ANTONIO DE JESUS LEITE
# ...             ...       ...                                        ...
# 1302464       25222         1                   ESCOLA ESTADUAL SAO JOSE
# 1302465          95        10         ESCOLA ESTADUAL LAURENTINO MARTINS
# 1302466       70190         1             ESCOLA MUNICIPAL CORA CORALINA
# 1302467       22580         1           ESCOLA MUNICIPAL MIGUEL PEDREIRO
# 1302468       45045        17  UNIDADE INTEGRADA SESI/SENAI - BARRO ALTO
#
#                          DS_LOCAL_VOTACAO_ENDERECO
# 0                             AV FERNANDO COSTA SN
# 1                             RUA GVE QD 08  LT 20
# 2                            QUADRA 32, LOTE 11/12
# 3        RUA ANTONIO INOCENCIO DE OLIVEIRA, NR 386
# 4                  AREA ESPECIAL QUADRA 15 LOTE 01
# ...                                            ...
# 1302464     CONJUNTO HABITACIONAL RIO VERMELHO SN
# 1302465                               RUA 36 N 391
# 1302466              RUA ILMA TIBURCIO BRAGA , S/N
# 1302467                           RUA MORRINHOS SN
# 1302468           RUA PEDRA DE FOGO, QD. 17 LT. 16
#
# [1302469 rows x 12 columns]

# %%
print(tse.isnull().sum())
# Out:
# ANO_ELEICAO                  0
# NM_MUNICIPIO                 0
# NR_ZONA                      0
# NR_SECAO                     0
# CD_TIPO_ELEICAO              0
# NR_TURNO                     0
# DS_CARGO                     0
# NM_VOTAVEL                   0
# NR_VOTAVEL                   0
# QT_VOTOS                     0
# NM_LOCAL_VOTACAO             0
# DS_LOCAL_VOTACAO_ENDERECO    0
# dtype: int64

# %%
# filtros

tse['NM_MUNICIPIO'].unique()
# Out:
# array(['ANAPOLIS', 'AGUAS LINDAS DE GOIAS', 'CALDAS NOVAS',
#        'FIRMINOPOLIS', 'POSSE', 'MOZARLANDIA', 'ADELANDIA', 'PIRACANJUBA',
#        'ITABERAI', 'JATAI', 'NOVO GAMA', 'BURITINOPOLIS', 'GOIANIA',
#        'HIDROLANDIA', 'PADRE BERNARDO', 'AMERICANO DO BRASIL',
#        'BELA VISTA DE GOIAS', 'RIO VERDE', 'APARECIDA DE GOIANIA',
#        'EDEIA', 'TRINDADE', 'CAVALCANTE', 'SENADOR CANEDO', 'CATALAO',
#        'ARACU', 'ITAPURANGA', 'QUIRINOPOLIS', 'ACREUNA',
#        'MONTIVIDIU DO NORTE', 'VALPARAISO DE GOIAS', 'PIRENOPOLIS',
#        'GOIAS', 'RIALMA', 'TEREZOPOLIS DE GOIAS', 'GAMELEIRA DE GOIAS',
#        'IPAMERI', 'PLANALTINA', 'LUZIANIA', 'GOIANESIA', 'ITUMBIARA',
#        'GOIANIRA', 'CIDADE OCIDENTAL', 'BURITI DE GOIAS', 'CRIXAS',
#        'JUSSARA', 'SAO MIGUEL DO ARAGUAIA', 'BRAZABRANTES', 'IPORA',
#        'VARJAO', 'FLORES DE GOIAS', 'SANTA BARBARA DE GOIAS',
#        'NIQUELANDIA', 'AMORINOPOLIS', 'CACHOEIRA ALTA', 'CRISTALINA',
#        'CAMPOS BELOS', 'URUANA', 'CARMO DO RIO VERDE', 'GOIANAPOLIS',
#        'SANTO ANTONIO DO DESCOBERTO', 'DOVERLANDIA', 'PORANGATU',
#        'CUMARI', 'ARAGARCAS', 'CERES', 'MARA ROSA', 'SANCLERLANDIA',
#        'GUAPO', 'AGUA FRIA DE GOIAS', 'MINEIROS', 'NEROPOLIS', 'JARAGUA',
#        'JANDAIA', 'CATURAI', 'SILVANIA', 'ARAGOIANIA', 'ARENOPOLIS',
#        'ITAPIRAPUA', 'TAQUARAL DE GOIAS', 'MONTIVIDIU', 'VILA PROPICIO',
#        'SAO SIMAO', 'INHUMAS', 'PALMEIRAS DE GOIAS', 'CAIAPONIA',
#        'URUACU', 'SANTA TEREZINHA DE GOIAS', 'CORUMBA DE GOIAS',
#        'VICENTINOPOLIS', 'RUBIATABA', 'SITIO D ABADIA',
#        'SANTA HELENA DE GOIAS', 'BARRO ALTO', 'MONTE ALEGRE DE GOIAS',
#        'CACU', 'CRISTIANOPOLIS', 'ANICUNS', 'AMARALINA', 'FORMOSA',
#        'CEZARINA', 'ALVORADA DO NORTE', 'AGUA LIMPA', 'FORMOSO',
#        'PARAUNA', 'DIORAMA', 'INDIARA', 'OURO VERDE DE GOIAS', 'GOIATUBA',
#        'ITAUCU', 'FAINA', 'SIMOLANDIA', 'MAURILANDIA', 'ARUANA',
#        'CAMPO LIMPO DE GOIAS', 'DAMOLANDIA', 'BURITI ALEGRE', 'ABADIANIA',
#        'PIRES DO RIO', 'HEITORAI', 'ALTO PARAISO DE GOIAS', 'MARZAGAO',
#        'CAMPOS VERDES', 'PEROLANDIA', 'BONFINOPOLIS', 'VILA BOA',
#        'PONTALINA', 'SAO DOMINGOS', 'ALEXANIA', 'PIRANHAS',
#        'COLINAS DO SUL', 'CASTELANDIA', 'COCALZINHO DE GOIAS',
#        'MATRINCHA', 'NOVA GLORIA', 'EDEALINA', 'PALMINOPOLIS',
#        'SAO FRANCISCO DE GOIAS', 'ORIZONA', 'PROFESSOR JAMIL',
#        'BOM JESUS DE GOIAS', 'SAO JOAO D ALIANCA', 'TRES RANCHOS',
#        'MINACU', 'CAMPINORTE', 'MORRINHOS', 'OUVIDOR', 'ABADIA DE GOIAS',
#        'HIDROLINA', 'MOIPORA', 'ESTRELA DO NORTE', 'VIANOPOLIS',
#        'MONTES CLAROS DE GOIAS', 'SAO PATRICIO', 'DAMIANOPOLIS',
#        'NOVA AURORA', 'SANTA ISABEL', 'BOM JARDIM DE GOIAS', 'CROMINIA',
#        'MAMBAI', 'ARAGUAPAZ', 'IVOLANDIA', 'CORREGO DO OURO', 'BRITANIA',
#        'ITAPACI', 'CAMPINACU', 'SANTA RITA DO NOVO DESTINO',
#        'SAO LUIS DE MONTES BELOS', 'SANTA RITA DO ARAGUAIA',
#        'PARANAIGUARA', 'IPIRANGA DE GOIAS', 'PALESTINA DE GOIAS',
#        'DIVINOPOLIS DE GOIAS', 'PETROLINA DE GOIAS', 'TURVANIA',
#        'DAVINOPOLIS', 'CABECEIRAS', 'CORUMBAIBA', 'JOVIANIA',
#        'SANTO ANTONIO DA BARRA', 'INACIOLANDIA', 'ALOANDIA',
#        'NOVA CRIXAS', 'APORE', 'GOUVELANDIA', 'PORTEIRAO', 'BONOPOLIS',
#        'SANTA TEREZA DE GOIAS', 'AVELINOPOLIS', 'CHAPADAO DO CEU',
#        'FAZENDA NOVA', 'NOVA IGUACU DE GOIAS', 'ITARUMA',
#        'CACHOEIRA DOURADA', 'ITAGUARU', 'NOVA VENEZA', 'GUARAITA',
#        'LEOPOLDO DE BULHOES', 'CALDAZINHA', 'JESUPOLIS', 'ITAJA',
#        'URUTAI', 'SANTA ROSA DE GOIAS', 'ITAGUARI', 'NOVA AMERICA',
#        'TURVELANDIA', 'RIO QUENTE', 'NAZARIO', 'GUARANI DE GOIAS',
#        'PALMELO', 'GOIANDIRA', 'GUARINOS', 'SAO LUIZ DO NORTE',
#        'MAIRIPOTABA', 'JAUPACI', 'ALTO HORIZONTE', 'NOVO BRASIL',
#        'TERESINA DE GOIAS', 'CAMPO ALEGRE DE GOIAS', 'RIANAPOLIS',
#        'BALIZA', 'SANTA FE DE GOIAS', 'NOVO PLANALTO', 'MUNDO NOVO',
#        'MUTUNOPOLIS', 'MOSSAMEDES', 'CACHOEIRA DE GOIAS',
#        'SAO JOAO DA PARAUNA', 'PORTELANDIA', 'CAMPESTRE DE GOIAS',
#        'SANTA CRUZ DE GOIAS', 'MIMOSO DE GOIAS', 'APARECIDA DO RIO DOCE',
#        'SERRANOPOLIS', 'SANTO ANTONIO DE GOIAS', 'ISRAELANDIA', 'PANAMA',
#        'IACIARA', 'TROMBAS', 'AURILANDIA', 'UIRAPURU',
#        'MORRO AGUDO DE GOIAS', 'ANHANGUERA', 'NOVA ROMA',
#        'PILAR DE GOIAS', 'LAGOA SANTA', 'SAO MIGUEL DO PASSA QUATRO'],
#       dtype=object)

# %%
tse.head()
# Out:
#     ANO_ELEICAO NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  NR_TURNO  \
# 67         2020      GOIANIA      135       260                2         1
# 68         2020      GOIANIA      127       475                2         1
# 69         2020      GOIANIA      146       311                2         1
# 74         2020      GOIANIA        1       470                2         1
# 75         2020      GOIANIA        1       470                2         1
#
#     DS_CARGO                 NM_VOTAVEL  NR_VOTAVEL  QT_VOTOS  \
# 67  VEREADOR  FERNANDO MARQUES FAUSTINO       40400         1
# 68  VEREADOR     JOAO BATISTA RODRIGUES       70234         1
# 69  VEREADOR        JOAO  SANDES JUNIOR       11123         2
# 74  VEREADOR        JOAO  SANDES JUNIOR       11123         2
# 75  VEREADOR     PAULO ROBERTO DE SOUSA       36361         1
#
#                                 NM_LOCAL_VOTACAO  \
# 67       ESCOLA MUNICIPAL VIRGINIA GOMES PEREIRA
# 68                                  COLEGIO META
# 69                  ESCOLA ESTADUAL JAIME CAMARA
# 74  ESCOLAS DE ENGENHARIA CIVIL E ELETRICA - UFG
# 75  ESCOLAS DE ENGENHARIA CIVIL E ELETRICA - UFG
#
#                             DS_LOCAL_VOTACAO_ENDERECO
# 67  AVENIDA HILARIO SEBASTIAO FIGUEIREDO, QD. 04, ...
# 68                        RUA CAPRI QD 48 LT 6 N. 220
# 69                 RUA BF-26 SN QD 31 BAIRRO FLORESTA
# 74  PRACA UNIVERSITARIA, S/NR - SETOR LESTE UNIVER...
# 75  PRACA UNIVERSITARIA, S/NR - SETOR LESTE UNIVER...

# %%
# Agregação com tabela zonas

# Ler o arquivo diretamente usando pandas e gcsfs
zonas_info = pd.read_csv('gs://trabalho-final-pdm/bronze/zonas_goiania', storage_options={"token": "google_default"})

zonas_info = zonas_info[['ZONA', 'LOCAL DE VOTACAO', 'ENDEREÇO', 'BAIRRO']]

# Aplica a transformação em todas as colunas de tipo string
for col in zonas_info.select_dtypes(include=["object"]).columns:
    zonas_info[col] = zonas_info[col].apply(transformar_string)
zonas_info
# Out:
#      ZONA                                   LOCAL DE VOTACAO  \
# 0       1        COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA
# 1     147                                    COLEGIO DESAFIO
# 2     136                   COLEGIO ESTADUAL JARDIM VILA BOA
# 3     127                        ESCOLA SESI JARDIM PLANALTO
# 4     127   COLEGIO ESTADUAL POLIVALENTE PROFO GOIANY PRATES
# ..    ...                                                ...
# 351   134  ESCOLA MUNICIPAL PROFESSOR SALMON GOMES FIGUEI...
# 352     2                       UNIALFA - UNIDADE PERIMETRAL
# 353   127                                    COLEGIO DEGRAUS
# 354   147                      ESCOLA MUNICIPAL ALTO DO VALE
# 355   133  ESCOLA MUNICIPAL PROFESSORA AMELIA FERNANDES M...
#
#                                          ENDEREÇO               BAIRRO
# 0                           AV K, 108 - UNIDADE I      SETOR AEROPORTO
# 1                          AV MANGALO QD 55 LT 06  SETOR MORADA DO SOL
# 2                            RUA PAOLA NEY QD. 59      JARDIM VILA BOA
# 3                          PRACA ITAPUA QD 30 150      JARDIM PLANALTO
# 4                             RUA C-68 QD 115 336      VILAS DOS ALPES
# ..                                            ...                  ...
# 351                RUA SAO DOMINGOS QD. 91 LT. 04   JARDIM PETROPOLIS
# 352                      AV PERIMETRAL NORTE 4129     SETOR GOIANIA II
# 353                                 RUA U-79A, 25          VILA UNIAO
# 354  RUA SAMIR HELOU COM RUA VF 15, QD. 6, LT. 19  SETOR ALTO DO VALE
# 355                                RUA OCANAN, 50     PARQUE ACALANTO
#
# [356 rows x 4 columns]

# %%
tse['NR_ZONA'] = tse['NR_ZONA'].astype(int)
zonas_info['ZONA'] = zonas_info['ZONA'].astype(int)

# %%
# Agrupar zonas_info pela coluna ZONA, garantindo que nenhuma informação seja perdida
zonas_info_agrupado = zonas_info.groupby("ZONA").agg({
    "LOCAL DE VOTACAO": lambda x: list(x),
    "ENDEREÇO": lambda x: list(x),
    "BAIRRO": lambda x: list(x)
}).reset_index()

# %%
# Realizar a junção das tabelas usando colunas com nomes diferentes
tse_unificado = pd.merge(
    tse, 
    zonas_info_agrupado, 
    left_on="NR_ZONA",  # Coluna na tabela tse
    right_on="ZONA", # Coluna na tabela zonas_info
    how="left"       # Manter todas as linhas de tse
)

# Remover a duplicata da coluna Zona, se necessário
tse_unificado.drop(columns=["ZONA"], inplace=True)

# Visualizar o resultado
tse_unificado
# Out:
#         ANO_ELEICAO NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_TIPO_ELEICAO  \
# 0              2020      GOIANIA      135       260                2
# 1              2020      GOIANIA      127       475                2
# 2              2020      GOIANIA      146       311                2
# 3              2020      GOIANIA        1       470                2
# 4              2020      GOIANIA        1       470                2
# ...             ...          ...      ...       ...              ...
# 336756         2020      GOIANIA        2       447                2
# 336757         2020      GOIANIA      136       544                2
# 336758         2020      GOIANIA      127         2                2
# 336759         2020      GOIANIA      127         2                2
# 336760         2020      GOIANIA        2       193                2
#
#         NR_TURNO  DS_CARGO                   NM_VOTAVEL  NR_VOTAVEL  QT_VOTOS  \
# 0              1  VEREADOR    FERNANDO MARQUES FAUSTINO       40400         1
# 1              1  VEREADOR       JOAO BATISTA RODRIGUES       70234         1
# 2              1  VEREADOR          JOAO  SANDES JUNIOR       11123         2
# 3              1  VEREADOR          JOAO  SANDES JUNIOR       11123         2
# 4              1  VEREADOR       PAULO ROBERTO DE SOUSA       36361         1
# ...          ...       ...                          ...         ...       ...
# 336756         1  VEREADOR       RONILSON DE SOUZA REIS       19600         1
# 336757         1  VEREADOR         JOSE DE SOUZA BORGES       10555         2
# 336758         1  VEREADOR  HENRIQUE ALVES LUIZ PEREIRA       15010         1
# 336759         1  VEREADOR      NILTON PEREIRA DA SILVA       10456         2
# 336760         1  VEREADOR  HENRIQUE ALVES LUIZ PEREIRA       15010         1
#
#                                     NM_LOCAL_VOTACAO  \
# 0            ESCOLA MUNICIPAL VIRGINIA GOMES PEREIRA
# 1                                       COLEGIO META
# 2                       ESCOLA ESTADUAL JAIME CAMARA
# 3       ESCOLAS DE ENGENHARIA CIVIL E ELETRICA - UFG
# 4       ESCOLAS DE ENGENHARIA CIVIL E ELETRICA - UFG
# ...                                              ...
# 336756                        COLEGIO GONCALVES LEDO
# 336757     ESCOLA MUNICIPAL GEORGETA RIVALINO DUARTE
# 336758                        ESCOLA CASA DAS LETRAS
# 336759                        ESCOLA CASA DAS LETRAS
# 336760                 ESCOLA MUNICIPAL DONA BELINHA
#
#                                 DS_LOCAL_VOTACAO_ENDERECO  \
# 0       AVENIDA HILARIO SEBASTIAO FIGUEIREDO, QD. 04, ...
# 1                             RUA CAPRI QD 48 LT 6 N. 220
# 2                      RUA BF-26 SN QD 31 BAIRRO FLORESTA
# 3       PRACA UNIVERSITARIA, S/NR - SETOR LESTE UNIVER...
# 4       PRACA UNIVERSITARIA, S/NR - SETOR LESTE UNIVER...
# ...                                                   ...
# 336756               RUA ARMOGASTE JOSE DA SILVEIRA N 300
# 336757                AV GENERAL CUNHA MATOS QD 27 LT 2/7
# 336758              RUA C-148, QD 380, LTS 18/21, N. 1136
# 336759              RUA C-148, QD 380, LTS 18/21, N. 1136
# 336760                                        RUA 12 N 70
#
#                                          LOCAL DE VOTACAO  \
# 0       [COLEGIO ESTADUAL IRMA GABRIELA, ESCOLA MUNICI...
# 1       [ESCOLA SESI JARDIM PLANALTO, COLEGIO ESTADUAL...
# 2       [CEPMGO WALDEMAR MUNDIM, CEPMGO JARDIM GUANABA...
# 3       [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# 4       [COLEGIO AGOSTINIANO NOSSA SENHORA DE FATIMA, ...
# ...                                                   ...
# 336756  [CENTRO DE ENSINO EM PERIODO INTEGRAL AECIO OL...
# 336757  [COLEGIO ESTADUAL JARDIM VILA BOA, COLEGIO MUN...
# 336758  [ESCOLA SESI JARDIM PLANALTO, COLEGIO ESTADUAL...
# 336759  [ESCOLA SESI JARDIM PLANALTO, COLEGIO ESTADUAL...
# 336760  [CENTRO DE ENSINO EM PERIODO INTEGRAL AECIO OL...
#
#                                                  ENDEREÇO  \
# 0       [RUA PLANALTO, AV. CRISTOVAO COLOMBO, 539, PRA...
# 1       [PRACA ITAPUA QD 30 150, RUA C-68 QD 115 336, ...
# 2       [RUA R-40 QD40 LT07, ALAMEDA MINAS GERAIS QD.7...
# 3       [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# 4       [AV K, 108 - UNIDADE I, AV E QD. B-11, RUA 18 ...
# ...                                                   ...
# 336756  [RUA CARIJOS COM RUA DO PRATA, AV SOL NASCENTE...
# 336757  [RUA PAOLA NEY QD. 59, RUA B-16 101, RUA 3 B Q...
# 336758  [PRACA ITAPUA QD 30 150, RUA C-68 QD 115 336, ...
# 336759  [PRACA ITAPUA QD 30 150, RUA C-68 QD 115 336, ...
# 336760  [RUA CARIJOS COM RUA DO PRATA, AV SOL NASCENTE...
#
#                                                    BAIRRO
# 0       [CONJUNTO RIVIERA, JARDIM NOVO MUNDO, JARDIM N...
# 1       [JARDIM PLANALTO, VILAS DOS ALPES, JARDIM AMER...
# 2       [VILA ITATIAIA, JARDIM GUANABARA, LESTE VILA N...
# 3       [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# 4       [SETOR AEROPORTO, JARDIM GOIAS, SETOR OESTE, S...
# ...                                                   ...
# 336756  [SETOR URIAS MAGALHAES, JARDIM NOVA ESPERANCA,...
# 336757  [JARDIM VILA BOA, VILA NOVO HORIZONTE, SETOR G...
# 336758  [JARDIM PLANALTO, VILAS DOS ALPES, JARDIM AMER...
# 336759  [JARDIM PLANALTO, VILAS DOS ALPES, JARDIM AMER...
# 336760  [SETOR URIAS MAGALHAES, JARDIM NOVA ESPERANCA,...
#
# [336761 rows x 15 columns]

# %%
tse_unificado.shape, tse.shape
# Out:
# ((336761, 15), (336761, 12))

# %%
# Salvar DataFrame diretamente no GCS
gcs_path = "gs://trabalho-final-pdm/silver/tse_bairros_2020.csv"

# Escrever para o Cloud Storage usando storage_options
tse_unificado.to_csv(gcs_path, index=False, storage_options={"token": "google_default"})
